# %% [markdown]
# # WMIR practice lesson on Spacy
#
# ### Obiettivi
# - Usare il framework Spacy per estrarre informazioni rilevanti dalle frasi per arricchire le loro rappresentazioni.
# - Addestra diversi modelli e confrontali con e senza la rappresentazioni "arricchita"
#
# #### Author
# Claudiu Daniel Hromei, April 2023.
# hromei@ing.uniroma2.it

# %% [markdown]
# # Introduzione
#
# [SpaCy](spacy.io) è una libreria open-source gratuita per il Natural Language Processing (NLP) in Python. Può essere usata per costruire sistemi di Information Extractrion o di Comprensione del Linguaggio Naturale, o anche per fare preprocessamento di testo per il Deep Learning.
# Alcune caratteristiche di SpaCy sono:
# - **Tokenization**: suddividere il testo in unità indivisibili (**token**), formate dalle singole parole, segni di punteggiatura, simboli come 35% ecc.
# - **Part-of-speech (POS) Tagging**: Assegnare i tipi delle parole (nome, verbo) ai token.
# - **Dependency Parsing**: Assegnare delle etichette di dipendenza sintattica che descrivono le relazioni tra i diversi token. Ad esempio un token è oggetto mentre un altro è il soggetto.
# - **Lemmatization**: Convertire le parole nella loro forma base, in italiano nel lemma. Ad esempio la forma all'infinto dei verbi oppure la forma maschile singolare dei nomi. In inglese, il lemma di “was” è “be”, e il lemma di “rats” è “rat”.
# - **Sentence Boundary Detection (SBD)**: Trovare e suddividere i testi nelle diverse frasi.
# - **Named Entity Recognition (NER)**: Trovare ed etichettare gli oggetti del mondo reale che hanno un nome, ad esempio persone, compagnie o luoghi. "New York City", "Giovanni" sono delle Named Entities.
# - **Entity Linking (EL)**: Disambiguare le entità testuali in modo da assegnargli degli identificatori univoci in una base di conoscenza.
# - **Similarity**: Confrontare le parole, testi e documenti e fornire una misura di similarità tra loro.
# - **Text Classification**: Assegnare delle categorie o etichette a interi documenti o parti di esso.
# - **Rule-based Matching**: Trovare le sequenze di token in base alle loro annotazioni linguistiche, in modo simile alle Regular Expression.
# - **Training**: Aggiornare e migliorare le predizioni di un modello statistico
# - **Serialization**: Salvare gli oggetti su file o su stringhe di bytes.

# %% [markdown]
# # Required Libraries

# %%
import pandas as pd

from IPython.display import display, HTML

# %%
# option to print all the value of cells in DataFrames
pd.set_option("max_colwidth", None)

# %% [markdown]
# ### Install spacy and download the english pipeline

# %%
# install the spacy module
# %pip install spacy
# Out:
# Requirement already satisfied: spacy in /home/giaco/PycharmProjects/CodiceML/venv/lib/python3.10/site-packages (3.5.2)
# Requirement already satisfied: jinja2 in /home/giaco/PycharmProjects/CodiceML/venv/lib/python3.10/site-packages (from spacy) (3.1.2)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /home/giaco/PycharmProjects/CodiceML/venv/lib/python3.10/site-packages (from spacy) (1.1.1)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /home/giaco/PycharmProjects/CodiceML/venv/lib/python3.10/site-packages (from spacy) (0.7.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/giaco/PycharmProjects/CodiceML/venv/lib/python3.10/site-packages (from spacy) (4.65.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/giaco/PycharmProjects/CodiceML/venv/lib/python3.10/site-packages (from spacy) (2.28.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/giaco/PycharmProjects/CodiceML/venv/lib/python3.10/site-packages (from spacy) (1.0.9)
# Requirement already satisfied: setuptools in /home/giaco/PycharmProjects/CodiceML/venv/lib/python3.10/site-packages (from spacy) (67.2.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/giaco/PycharmProjects/CodiceML/venv/lib/python3.10/site-packages (from spacy) (3.3.0)
# Requirement already satisfied: pathy>=0.10.0 in /home/giaco/PycharmProjects/CodiceML/venv/lib/python3.10/site-packages (from spacy) (0.10.1)
# Requirement already satisfied: packaging>=20.0 in /home/giaco/PycharmProjects/CodiceML/venv/lib/python3.10/site-packages (from spacy) (23.0)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/giaco/PycharmProjects/CodiceML/venv/lib/python3.10/site-packages (from spacy) (1.0.4)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/giaco/PycharmProjects/CodiceML/venv/lib/python3.10/site-packages (from spacy) (3.0.8)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /home/giaco/PycharmProjects/CodiceML/venv/lib/python3.10/site-packages (from spacy) (8.1.9)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /home/giaco/PycharmProjects/CodiceML/venv/lib/python3.10/site-packages (from spacy) (1.10.7)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /home/giaco/PycharmProjects/CodiceML/venv/lib/python3.10/site-packages (from spacy) (3.0.12)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/giaco/PycharmProjects/CodiceML/venv/lib/python3.10/site-packages (from spacy) (2.0.8)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /home/giaco/PycharmProjects/CodiceML/venv/lib/python3.10/site-packages (from spacy) (6.3.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /home/giaco/PycharmProjects/CodiceML/venv/lib/python3.10/site-packages (from spacy) (2.4.6)
# Requirement already satisfied: numpy>=1.15.0 in /home/giaco/PycharmProjects/CodiceML/venv/lib/python3.10/site-packages (from spacy) (1.24.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/giaco/PycharmProjects/CodiceML/venv/lib/python3.10/site-packages (from spacy) (2.0.7)
# Requirement already satisfied: typing-extensions>=4.2.0 in /home/giaco/PycharmProjects/CodiceML/venv/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy) (4.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/giaco/PycharmProjects/CodiceML/venv/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/giaco/PycharmProjects/CodiceML/venv/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.15)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/giaco/PycharmProjects/CodiceML/venv/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/giaco/PycharmProjects/CodiceML/venv/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /home/giaco/PycharmProjects/CodiceML/venv/lib/python3.10/site-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /home/giaco/PycharmProjects/CodiceML/venv/lib/python3.10/site-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.0.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /home/giaco/PycharmProjects/CodiceML/venv/lib/python3.10/site-packages (from typer<0.8.0,>=0.3.0->spacy) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/giaco/PycharmProjects/CodiceML/venv/lib/python3.10/site-packages (from jinja2->spacy) (2.1.2)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.5.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.5.0/en_core_web_sm-3.5.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 1.2 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: spacy<3.6.0,>=3.5.0 in /home/giaco/PycharmProjects/CodiceML/venv/lib/python3.10/site-packages (from en-core-web-sm==3.5.0) (3.5.2)
# Requirement already satisfied: setuptools in /home/giaco/PycharmProjects/CodiceML/venv/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (67.2.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /home/giaco/PycharmProjects/CodiceML/venv/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.0.12)
# Requirement already satisfied: pathy>=0.10.0 in /home/giaco/PycharmProjects/CodiceML/venv/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.10.1)
# Requirement already satisfied: packaging>=20.0 in /home/giaco/PycharmProjects/CodiceML/venv/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (23.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /home/giaco/PycharmProjects/CodiceML/venv/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (6.3.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/giaco/PycharmProjects/CodiceML/venv/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.3.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/giaco/PycharmProjects/CodiceML/venv/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.0.8)
# Requirement already satisfied: numpy>=1.15.0 in /home/giaco/PycharmProjects/CodiceML/venv/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.24.2)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /home/giaco/PycharmProjects/CodiceML/venv/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (8.1.9)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /home/giaco/PycharmProjects/CodiceML/venv/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.7.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/giaco/PycharmProjects/CodiceML/venv/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.0.7)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/giaco/PycharmProjects/CodiceML/venv/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.0.9)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/giaco/PycharmProjects/CodiceML/venv/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.28.2)
# Requirement already satisfied: jinja2 in /home/giaco/PycharmProjects/CodiceML/venv/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.1.2)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/giaco/PycharmProjects/CodiceML/venv/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.0.4)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/giaco/PycharmProjects/CodiceML/venv/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.0.8)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/giaco/PycharmProjects/CodiceML/venv/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (4.65.0)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /home/giaco/PycharmProjects/CodiceML/venv/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.1.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /home/giaco/PycharmProjects/CodiceML/venv/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.10.7)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /home/giaco/PycharmProjects/CodiceML/venv/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.4.6)
# Requirement already satisfied: typing-extensions>=4.2.0 in /home/giaco/PycharmProjects/CodiceML/venv/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (4.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/giaco/PycharmProjects/CodiceML/venv/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /home/giaco/PycharmProjects/CodiceML/venv/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/giaco/PycharmProjects/CodiceML/venv/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.1.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/giaco/PycharmProjects/CodiceML/venv/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.26.15)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /home/giaco/PycharmProjects/CodiceML/venv/lib/python3.10/site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /home/giaco/PycharmProjects/CodiceML/venv/lib/python3.10/site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.0.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /home/giaco/PycharmProjects/CodiceML/venv/lib/python3.10/site-packages (from typer<0.8.0,>=0.3.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/giaco/PycharmProjects/CodiceML/venv/lib/python3.10/site-packages (from jinja2->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.1.2)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1
# [notice] To update, run: pip install --upgrade pip
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import spacy
from spacy import displacy

# %% [markdown]
# # Esempio di annotazione
# Vogliamo stampare le annotazioni sintattiche di una frase.

# %%
input_string = "In 1982, Mark drove his car from Los Angeles to Las Vegas until 5 of july"
nlp = spacy.load('en_core_web_sm')

# %%
def print_annotation(input_string):
    # esegue il modello del linguaggio sulla stringa in input
    # dal doc possiamo estrarre molte cose, come le frasi, le singole parole, le relazioni ecc.
    doc = nlp(input_string)

    words = []
    # per ogni frase del documento
    for sent in doc.sents:
        # per ogni parola di indice i della frase
        for i, word in enumerate(sent):
            if word.head is word:
                head_idx = 0
            else:
                head_idx = doc[i].head.i+1
            if head_idx == i + 1:
                head_idx = 0

            entity_tag = word.ent_type_
            if len(entity_tag) == 0:
                entity_tag = "O"
        
            word_obj = {
                "id": str(i+1), 
                "word": str(word), 
                "lemma": word.lemma_, 
                "tag": word.tag_, 
                "pos": word.pos_,
                "entity": entity_tag,
                "dependency": word.dep_, 
                "head_id": str(head_idx)
            }
            words.append(word_obj)

    df = pd.DataFrame(words, columns=["id", "word", "lemma", "tag", "pos", "entity", "dependency", "head_id"])
    display(df) # stampiamo tutte le dipendenze tra parole, il lemma, il tag, il tipo di entità

# %% [markdown]
# - O: significa other. Nella colonna entity vuol dire che non fa parte di nessuna entità;
# - Root: nella colonna dependency vuol dire che non ha nessuna dipendenza in entrata;

# %%
print_annotation(input_string)
# Out:
#     id     word    lemma   tag    pos  entity dependency head_id
# 0    1       In       in    IN    ADP       O       prep       5
# 1    2     1982     1982    CD    NUM    DATE       pobj       1
# 2    3        ,        ,     ,  PUNCT       O      punct       5
# 3    4     Mark     Mark   NNP  PROPN  PERSON      nsubj       5
# 4    5    drove    drive   VBD   VERB       O       ROOT       0
# 5    6      his      his  PRP$   PRON       O       poss       7
# 6    7      car      car    NN   NOUN       O       dobj       5
# 7    8     from     from    IN    ADP       O       prep       5
# 8    9      Los      Los   NNP  PROPN     GPE   compound      10
# 9   10  Angeles  Angeles   NNP  PROPN     GPE       pobj       8
# 10  11       to       to    IN    ADP       O       prep       5
# 11  12      Las      Las   NNP  PROPN     GPE   compound      13
# 12  13    Vegas    Vegas   NNP  PROPN     GPE       pobj      11
# 13  14    until    until    IN    ADP       O       prep       5
# 14  15        5        5    CD    NUM    DATE       pobj      14
# 15  16       of       of    IN    ADP    DATE       prep      15
# 16  17     july     july   NNP  PROPN    DATE       pobj      16

# %%
# Giacomo: mia aggiunta per capire esercizio 3.
sentence_2_verbs_by_giacomo = "John was eating an apple, but the apple fell to the ground."
print_annotation(sentence_2_verbs_by_giacomo)
# Out:
#     id    word   lemma  tag    pos  entity dependency head_id
# 0    1    John    John  NNP  PROPN  PERSON      nsubj       3
# 1    2     was      be  VBD    AUX       O        aux       3
# 2    3  eating     eat  VBG   VERB       O       ROOT       0
# 3    4      an      an   DT    DET       O        det       5
# 4    5   apple   apple   NN   NOUN       O       dobj       3
# 5    6       ,       ,    ,  PUNCT       O      punct       3
# 6    7     but     but   CC  CCONJ       O         cc       3
# 7    8     the     the   DT    DET       O        det       9
# 8    9   apple   apple   NN   NOUN       O      nsubj      10
# 9   10    fell    fall  VBD   VERB       O       conj       3
# 10  11      to      to   IN    ADP       O       prep      10
# 11  12     the     the   DT    DET       O        det      13
# 12  13  ground  ground   NN   NOUN       O       pobj      11
# 13  14       .       .    .  PUNCT       O      punct      10

# %%
sentence_without_proper_name = "The thing is we do not have a choice!"
print_annotation(sentence_without_proper_name)
# Out:
#    id    word   lemma  tag    pos entity dependency head_id
# 0   1     The     the   DT    DET      O        det       2
# 1   2   thing   thing   NN   NOUN      O      nsubj       3
# 2   3      is      be  VBZ    AUX      O       ROOT       0
# 3   4      we      we  PRP   PRON      O      nsubj       7
# 4   5      do      do  VBP    AUX      O        aux       7
# 5   6     not     not   RB   PART      O        neg       7
# 6   7    have    have   VB   VERB      O      ccomp       3
# 7   8       a       a   DT    DET      O        det       9
# 8   9  choice  choice   NN   NOUN      O       dobj       7
# 9  10       !       !    .  PUNCT      O      punct       3

# %%
def visualize_annotation(input_string, style="dep"):
    doc = nlp(input_string)
    # Lo stile può essere "dep" per visualizzare le dipendenze tra le parole o "ent" per visualizzare le named entities
    displacy.render(doc, style=style, jupyter=True, options={"distance": 140}) # aumenta la distance per migliorare la leggibilità (default 140)

# %%
visualize_annotation(input_string, style="dep")
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="1892c8e950df458aaae9f7f9e439cd1d-0" class="displacy" width="2290" height="487.0" direction="ltr" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">In</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="190">1982,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="190">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="330">Mark</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="330">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="470">drove</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="470">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="610">his</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="610">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">car</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="890">from</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1030">Los</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1030">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1170">Angeles</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1170">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1310">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1310">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">Las</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1590">Vegas</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1590">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1730">until</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1730">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1870">5</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1870">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2010">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2010">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">july</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-1892c8e950df458aaae9f7f9e439cd1d-0-0" stroke-width="2px" d="M70,352.0 C70,212.0 455.0,212.0 455.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-1892c8e950df458aaae9f7f9e439cd1d-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,354.0 L62,342.0 78,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-1892c8e950df458aaae9f7f9e439cd1d-0-1" stroke-width="2px" d="M70,352.0 C70,282.0 170.0,282.0 170.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-1892c8e950df458aaae9f7f9e439cd1d-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M170.0,354.0 L178.0,342.0 162.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-1892c8e950df458aaae9f7f9e439cd1d-0-2" stroke-width="2px" d="M350,352.0 C350,282.0 450.0,282.0 450.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-1892c8e950df458aaae9f7f9e439cd1d-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M350,354.0 L342,342.0 358,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-1892c8e950df458aaae9f7f9e439cd1d-0-3" stroke-width="2px" d="M630,352.0 C630,282.0 730.0,282.0 730.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-1892c8e950df458aaae9f7f9e439cd1d-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">poss</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M630,354.0 L622,342.0 638,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-1892c8e950df458aaae9f7f9e439cd1d-0-4" stroke-width="2px" d="M490,352.0 C490,212.0 735.0,212.0 735.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-1892c8e950df458aaae9f7f9e439cd1d-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M735.0,354.0 L743.0,342.0 727.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-1892c8e950df458aaae9f7f9e439cd1d-0-5" stroke-width="2px" d="M490,352.0 C490,142.0 880.0,142.0 880.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-1892c8e950df458aaae9f7f9e439cd1d-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M880.0,354.0 L888.0,342.0 872.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-1892c8e950df458aaae9f7f9e439cd1d-0-6" stroke-width="2px" d="M1050,352.0 C1050,282.0 1150.0,282.0 1150.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25

# %%
visualize_annotation(input_string, style="ent") # GPE = Global Position Entity
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">In
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1982
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mark
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  drove his car from
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Los Angeles
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  to
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Las Vegas
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  until
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     5 of july
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </div></span>

# %% [markdown]
# # Information extraction
#
# Il seguente metodo permette di ottenere informazioni su una singola parola della frase in input.

# %%
def get_word_annotation(input_string, word_string):
    doc = nlp(input_string)
    
    words = []
    for sent in doc.sents:
        for i, word in enumerate(sent):
            if word.head is word:
                head_idx = 0
            else:
                head_idx = doc[i].head.i+1
            if head_idx == i + 1:
                head_idx = 0

            entity_tag = word.ent_type_
            if len(entity_tag) == 0:
                entity_tag = "O"
            
            word_obj = {
                "id": i+1,
                "word": str(word), 
                "lemma": word.lemma_, 
                "tag": word.tag_, 
                "entity": entity_tag,
                "dependency": word.dep_, 
                "head id": head_idx
            }
            words.append(word_obj)
    
    for word in words:
        if word["word"] == word_string:
            return word
    
    return None

# %%
print(get_word_annotation(input_string, "Mark"))
# Out:
# {'id': 4, 'word': 'Mark', 'lemma': 'Mark', 'tag': 'NNP', 'entity': 'PERSON', 'dependency': 'nsubj', 'head id': 5}

# %% [markdown]
# ### Esercizio 1: Trovare le relazioni (dependencies)
#
# Definisci un metodo che prende in input una frase (`input_string`) e il nome di una relazione (`relation_string`), analizza l'input con spacy e restituisce le triple (w1, w2, relation) dove w è un lemma. Se la relazione non p presente, restituisce un array vuoto.
#
# ```python
# def search_relation(input_string, relation_string):
#     # your code here...
#     return word_obj_list
# ```

# %%
from typing import Callable, Dict, List
from spacy.tokens import Token

class Word:
    def __init__(self, word: Token, id: int, head_idx: int, entity_tag: str):        
        self.id = id
        self.word = str(word)
        self.lemma = word.lemma_
        self.tag = word.tag_
        self.pos = word.pos_
        self.entity = entity_tag
        self.dependency = word.dep_
        self.head_id = str(head_idx)
    
    # rappresentazione leggibile dell'oggetto (per utenti)
    def __str__(self):
        return "Word [" + \
            f"id: {self.id}, " +  \
            f"word: {self.word}, " +  \
            f"lemma: {self.lemma}, " +  \
            f"tag: {self.tag}, " + \
            f"pos: {self.pos}, " + \
            f"entity: {self.entity}, " +  \
            f"dependency: {self.dependency}, " +  \
            f"head_id: {self.head_id}" + \
        "]"   
        

    # rapprsentazione non ambigua dell'oggetto (per sviluppatori)
    def __repr__(self):
        return self.word  

# questa parte di codice la riutilizzo anche dopo: data una frase restituisce la lista di parole con tutte le informazioni utili di spacy
def _word_data(sentence: str, is_dict: bool):
    doc = nlp(sentence)
    if is_dict:
        words: Dict[int, Word] = {}
    else:
        words: List[Word] = []
    for sent in doc.sents:
        for i, word in enumerate(sent):
            if word.head is word:
                head_idx = 0
            else:
                head_idx = doc[i].head.i+1
            if head_idx == i + 1:
                head_idx = 0

            entity_tag = word.ent_type_
            if len(entity_tag) == 0:
                entity_tag = "O"

            word_obj = Word(word, i+1, head_idx, entity_tag)
            
            if is_dict:
                words[word_obj.id] = word_obj
            else:
                words.append(word_obj)
    return words

def get_word_data_list(sentence: str) -> List[Word]:
    return _word_data(sentence=sentence, is_dict=False)

def get_word_data_dict(sentence: str) -> Dict[int, Word]:
    return _word_data(sentence=sentence, is_dict=True)

# %%
def search_relation(input_string, relation_string):
    words: List[Word] = get_word_data_list(input_string)

    word_obj_set = set()
    for word_obj in words:
        w1 = word_obj.word
        dep = word_obj.dependency
        
        # trova la parola collegata dall'id
        head_id = word_obj.head_id
        w2 = "-"
        for word_obj in words:
            if head_id == word_obj.id:
                w2 = word_obj.word
                break

        # evito le relazioni duplicate
        if (head_id, id, dep) not in word_obj_set and relation_string == dep:
            word_obj_set.add((w1, w2, dep))
    
    return list(word_obj_set)

# %% [markdown]
# Ad esempio, cerchiamo tutte le parole in cui una è preposizione dell'altra

# %%
search_relation(input_string, "prep")
# Out:
# [('to', '-', 'prep'),
#  ('In', '-', 'prep'),
#  ('from', '-', 'prep'),
#  ('until', '-', 'prep'),
#  ('of', '-', 'prep')]

# %% [markdown]
# ### Esercizio 2: Trovare le entità
# Definire un metodo che prende in input una frase (`input_string`) e il nome di un tipo di entità (`entity_type_string`), analizza con spacy l'input e restituisce le parole (cioè gli `objects`, non le stringhe) descritti da quella entità. Se il tipo dell'entità non è presente, restituisce un array vuoto.
#
# ```python
# def search_entity(input_string, entity_type_string):
#     return word_obj_list
# ```

# %%
# Vanno restituiti gli object (e.g. "Los Angeles"), non le singole stringhe "Los" e "Angeles"

def search_entity(input_string, ent_label):
    entities_list = []
    doc = nlp(input_string)
    for ent in doc.ents:
        if ent.label_ == ent_label:
            entities_list.append((ent.text, ent.label_))
    return entities_list

# %%
entities = search_entity(input_string, "GPE") # GPE | DATE
print(entities)
# Out:
# [('Los Angeles', 'GPE'), ('Las Vegas', 'GPE')]

# %% [markdown]
# ### Esercizio 3: Arricchire le frasi
# Per ogni frase nel dataset QuestionClassification, estrai le relazioni `subject-verb` e `verb-object`. Aggiungi queste coppie all'input originale, divise dal simbolo `#`. Ad esempio:
#
# - Frase: '*What is the full form of .com?*'
# - `subject-verb`: *What is*
# - `verb-object`: *is the full form*
# - Frase arricchita: '*What is the full form of .com? # What is # is the full form*'
#
# Salva le frasi arricchite in un nuovo dataframe, addestra un classificatore (SVM, NB, Rocchio..) e valutalo.

# %%
def enrich_sentence(input_sentence: str) -> str:
    words: List[Word] = get_word_data_list(input_sentence)
    subjects = find_subject(words)
    objects = find_object(words)

    words_dict: Dict[int, Word] = get_word_data_dict(input_sentence)
    result_str = input_sentence
    
    # aggiungo subject-verb
    for sub in subjects:
        # trovo il verbo
        verb = words_dict[int(sub.head_id)]

        # trovo eventuali parole collegate
        sub_words = []
        for word in words:
            if word.id == int(word.head_id):
                sub_words.append(word)
        # riordino
        sub_words.append(sub)
        sub_words.sort(key=lambda w: w.id)
        complete_sub = ""
        # traduco in stringa
        for sw in sub_words:
            complete_sub += sw.word + " "

        result_str += f" ~ {complete_sub}{verb.word}"
    
    # soggetto sottinteso
    if len(subjects) == 0:
        result_str += " ~ You"


    # aggiungo verb-object
    for obj in objects:
        # trovo il verbo
        verb = words_dict.get(int(obj.head_id))

        # trovo eventuali parole collegate
        obj_words = []
        for word in words:
            if obj.id == int(word.head_id):
                obj_words.append(word)
        obj_words.append(obj)
        # riordino
        obj_words.sort(key=lambda w: w.id)
        complete_obj = ""
        # traduco in stringa
        l = len(obj_words)
        for i, ow in enumerate(obj_words):
            complete_obj += ow.word
            if l != i + 1:
                complete_obj += " "

        if verb != None:
            result_str += f" # {verb.word} {complete_obj}"
        else:
            result_str += f" # {complete_obj}"

    return result_str

    

def find_subject(words: List[Word]) -> List[Word]:
    possible_subjects = ["attr", "advmod"]
    return list(filter(lambda w: (w.dependency in possible_subjects and (w.id == 1)) or w.word == "Who",  words))
    


def find_object(words: List[Word]) -> List[Word]:
    possible_objects = ["nsubj", "dobj", "dative", "oprd"]
    return list(filter(lambda w: w.dependency in possible_objects and w.word != "Who",  words))
    
def find_verb(words: List[Word]) -> List[Word]:
    possible_verbs = ["ROOT", "relcl"]
    return list(filter(lambda w: w.dependency in possible_verbs,  words))

# %%
sents = [
    "What is the full form of .com?",
    "Where is the Orinoco ?",
    "What is the best way to overcome a fear ?",
    "Name a South African diamond producer ?" ,
    "Why do heavier objects travel downhill faster ?", 
    "Who made the musical plea Be True to Your School ?"
]

for s in sents:
    print(enrich_sentence(s))

print_annotation(sents[5])
# Out:
# What is the full form of .com? ~ What is # is the full form of
# Where is the Orinoco ? ~ Where is # is the Orinoco
# What is the best way to overcome a fear ? ~ What is # is the best way overcome # overcome a fear
# Name a South African diamond producer ? ~ You # Name a African diamond producer
# Why do heavier objects travel downhill faster ? ~ Why travel # travel heavier objects
# Who made the musical plea Be True to Your School ? ~ Who made # Be the musical plea
#     id     word    lemma   tag    pos entity dependency head_id
# 0    1      Who      who    WP   PRON      O      nsubj       2
# 1    2     made     make   VBD   VERB      O       ROOT       0
# 2    3      the      the    DT    DET      O        det       5
# 3    4  musical  musical    JJ    ADJ      O       amod       5
# 4    5     plea     plea    NN   NOUN      O      nsubj       6
# 5    6       Be       be    VB    AUX      O      ccomp       2
# 6    7     True     true    JJ    ADJ      O      acomp       6
# 7    8       to       to    IN    ADP      O       prep       7
# 8    9     Your     your  PRP$   PRON      O       poss      10
# 9   10   School   school    NN   NOUN      O       pobj       8
# 10  11        ?        ?     .  PUNCT      O      punct       2

# %%
# arricchiamo il dataset (ci vuole un po'!)
from sklearn.feature_extraction.text import TfidfVectorizer

# NON E' PERFETTO, ma qualcosa fa (Impiega 52s sul mio PC)
def enrich(df) -> pd.DataFrame:
    data_dict = df.to_dict()
    questions : Dict[int, str] = data_dict["questions"]
    c = 0
    items = questions.items()
    l = len(items)
    for i, question in items:
        sentence_enriched = enrich_sentence(question)

        question = data_dict["questions"][i]

        if question != None:
            data_dict["questions"][i] = sentence_enriched
        else:
            f"question with id {i} skipped"
        
        c += 1
        print(f" {c}/{l} - {sentence_enriched}")
    return pd.DataFrame(data_dict)


training_data = pd.read_csv("./Dataset04svm/train.csv")
testing_data = pd.read_csv("./Dataset04svm/test.csv")


enriched_training_data = enrich(training_data)
enriched_testing_data = enrich(testing_data)
# Out:
#  1/5452 - How did serfdom develop in and then leave Russia ? ~ How develop # develop serfdom # leave Russia
#  2/5452 - What films featured the character Popeye Doyle ? ~ You # featured What films # featured the character Doyle
#  3/5452 - How can I find a list of celebrities ' real names ? ~ How find # find I # find a list of
#  4/5452 - What fowl grabs the spotlight after the Chinese Year of the Monkey ? ~ You # grabs What fowl # grabs the spotlight
#  5/5452 - What is the full form of .com ? ~ What is # is the full form of
#  6/5452 - What contemptible scoundrel stole the cork from my lunch ? ~ You # stole What contemptible scoundrel # stole the cork
#  7/5452 - What team did baseball 's St. Louis Browns become ? ~ You # did What team # become baseball Louis Browns
#  8/5452 - What is the oldest profession ? ~ What is # is the oldest profession
#  9/5452 - What are liver enzymes ? ~ What are # are liver enzymes
#  10/5452 - Name the scar-faced bounty hunter of The Old West . ~ You # Name the faced bounty hunter of
#  11/5452 - When was Ozzy Osbourne born ? ~ When was # born Ozzy Osbourne
#  12/5452 - Why do heavier objects travel downhill faster ? ~ Why travel # travel heavier objects
#  13/5452 - Who was The Pride of the Yankees ? ~ Who was
#  14/5452 - Who killed Gandhi ? ~ Who killed # killed Gandhi
#  15/5452 - What is considered the costliest disaster the insurance industry has ever faced ? ~ You # considered the costliest disaster faced # faced the insurance industry
#  16/5452 - What sprawling U.S. state boasts the most airports ? ~ You # boasts What sprawling U.S. state # boasts the most airports
#  17/5452 - What did the only repealed amendment to the U.S. Constitution deal with ? ~ You # deal the only repealed amendment to
#  18/5452 - How many Jews were executed in concentration camps during WWII ? ~ How many
#  19/5452 - What is `` Nine Inch Nails '' ? ~ You # is What
#  20/5452 - What is an annotated bibliography ? ~ What is # is an annotated bibliography
#  21/5452 - What is the date of Boxing Day ? ~ What is # is the date of
#  22/5452 - What articles of clothing are tokens in Monopoly ? ~ You # are What articles of
#  23/5452 - Name 11 famous martyrs . ~ You # Name 11 famous martyrs
#  24/5452 - What 's the Olympic motto ? ~ What 's # 's the Olympic motto
#  25/5452 - What is the origin of the name ` Scarlett ' ? ~ What is # is the origin of Scarlett
#  26/5452 - What 's the second-most-used vowel in English ? ~ What 's # 's the used vowel in
#  27/5452 - Who was the inventor of silly putty ? ~ Who was # was the inventor of
#  28/5452 - What is the highest waterfall in the United States ? ~ What is # is the highest waterfall in
#  29/5452 - Name a golf course in Myrtle Beach . ~ You # Name a golf course in
#  30/5452 - Which two states enclose Chesapeake Bay ? ~ You # enclose Which two states # enclose Chesapeake Bay
#  31/5452 - What does the abbreviation AIDS stand for ? ~ You # does What # does the abbreviation stand # stand AIDS
#  32/5452 - What does a spermologer collect ? ~ You # collect What
#  33/5452 - How many points make up a perfect fivepin bowling score ? ~ How many # make many points # make a perfect fivepin bowling score
#  34/5452 - Which company that manufactures video-game hardware sells the `` super system '' ? ~ You # sells Which company manufactures # manufactures that # manufactures game hardware # sells the ` ` super system ''
#  35/5452 - How many Community Chest cards are there in Monopoly ? ~ How many # are many Chest cards
#  36/5452 - What do Mormons believe ? ~ You # believe What # believe Mormons
#  37/5452 - When did the neanderthal man live ? ~ When live # live the neanderthal man
#  38/5452 - In what religion was Isis the nature goddess ? ~ You # was Isis
#  39/5452 - Where do the adventures of `` The Swiss Family Robinson '' take place ? ~ Where take # take the adventures of # take place
#  40/5452 - What relative of the racoon is sometimes known as the cat-bear ? ~ You
#  41/5452 - How can I register my website in Yahoo for free ? ~ How register # register I # register my website
#  42/5452 - What was cash-conscious Colonel Edwin L. Drake the first to drill ? ~ What was # was conscious Colonel Edwin L. Drake
#  43/5452 - How many people in the world speak French ? ~ How many # speak many people in # speak French
#  44/5452 - How many inches over six feet is the Venus de Milo ? ~ How many # is many inches feet
#  45/5452 - How do they find or choose witnesses to an execution ? ~ How find # find they # choose witnesses
#  46/5452 - What 1920s cowboy star rode Tony the Wonder Horse ? ~ You # rode What # rode 1920s cowboy star
#  47/5452 - What cocktail inspired John Doxat to write the book Stirred-Not Shaken ? ~ You # inspired What cocktail # inspired John Doxat # write the book # write Stirred Shaken
#  48/5452 - What ISPs exist in the Caribbean ? ~ You # exist What # exist ISPs
#  49/5452 - How do you ask a total stranger out on a date ? ~ How ask # ask you # ask a total stranger
#  50/5452 - What weapon is the mythological character Apollo most proficient with ? ~ You
#  51/5452 - What country do the Galapagos Islands belong to ? ~ You # belong the Galapagos Islands
#  52/5452 - What is ethology ? ~ What is # is ethology
#  53/5452 - Who was the prophet of the Muslim people ? ~ Who was # was the prophet of
#  54/5452 - Where did the term `` 86ed '' come from ? ~ You # come the term 86ed
#  55/5452 - Who is Snoopy 's arch-enemy ? ~ Who is
#  56/5452 - What is the nature of learning ? ~ What is # is the nature of
#  57/5452 - What 's the only color Johnny Cash wears on stage ? ~ What 's # 's the color Cash wears on
#  58/5452 - What 's the term for a young fox ? ~ What 's # 's the term for
#  59/5452 - What U.S. state lived under six flags ? ~ You # lived What # lived U.S. state
#  60/5452 - What is the Kashmir issue ? ~ What is # is the Kashmir issue
#  61/5452 - Where is the Loop ? ~ Where is # is the Loop
#  62/5452 - What does `` extended definition '' mean and how would one write a paper on it ? ~ You # definition What # mean What does ` ` extended definition '' # write one # write a paper
#  63/5452 - What country 's capital is Tirana ? ~ You # is country capital
#  64/5452 - What is titanium ? ~ What is # is titanium
#  65/5452 - Who do Herb and Tootsie live next door to ? ~ Who do # live Herb and Tootsie
#  66/5452 - Which city has the oldest relationship as a sister city with Los Angeles ? ~ You # has Which city # has the oldest relationship as
#  67/5452 - What is a caldera ? ~ What is # is a caldera
#  68/5452 - Why do people get calluses ? ~ Why get # get people # get calluses
#  69/5452 - What are the names of the tourist attractions in Reims ? ~ What are # are the names of
#  70/5452 - What are Cushman and Wakefield known for ? ~ What are # known Cushman and Wakefield
#  71/5452 - What body of water does the Danube River flow into ? ~ You # flow What body of # flow the Danube River
#  72/5452 - Who is the founder of Scientology ? ~ Who is # is the founder of
#  73/5452 - What does the six-footed Musca domestica become when it enters a house ? ~ You # become What # become the footed Musca domestica # enters it # enters a house
#  74/5452 - What is the history of skateboarding ? ~ What is # is the history of
#  75/5452 - Who starred in Singing in the Rain and The Singing Nun ? ~ Who starred
#  76/5452 - How do I make fuel bricks from recycled newspaper ? ~ How make # make I # make fuel bricks
#  77/5452 - What 19th-century painter died in the Marquesas Islands ? ~ You # died What century painter
#  78/5452 - The corpus callosum is in what part of the body ? ~ You # is The corpus callosum
#  79/5452 - How do I log on to home page at Headquarters U.S. European Command ? ~ How log # log I
#  80/5452 - What country did the Nazis occupy for 1 , CD NNS IN NNP NNP NNP . ~ You # occupy What country # occupy the Nazis
#  81/5452 - What is Nebraska 's most valuable resource ? ~ What is # is Nebraska valuable resource
#  82/5452 - How many species of the Great White shark are there ? ~ How many # are many species of
#  83/5452 - What is the origin of head lice ? ~ What is # is the origin of
#  84/5452 - What is the nickname for the state of Mississippi ? ~ What is # is the nickname for
#  85/5452 - What was the first domesticated bird ? ~ What was # was the domesticated bird
#  86/5452 - How many villi are found in the small intestine ? ~ How many
#  87/5452 - What country did King Wenceslas rule ? ~ You # did What country # rule King Wenceslas
#  88/5452 - What is a fear of shadows ? ~ What is # is a fear of
#  89/5452 - Who were the five Marx brothers ? ~ Who were
#  90/5452 - In which year was New Zealand excluded from the ANZUS alliance ? ~ You # excluded New Zealand
#  91/5452 - When did CNN begin broadcasting ? ~ When begin # begin CNN
#  92/5452 - What causes the body to shiver in cold temperatures ? ~ You # causes What # shiver the body
#  93/5452 - What are bear and bull markets ? ~ What are # are bear markets
#  94/5452 - What J.R.R. Tolkien book features Bilbo Baggins as the central character ? ~ You # features What # features Tolkien book # features Bilbo Baggins
#  95/5452 - What is `` dew point '' ? ~ You # is What # is ` ` dew point ''
#  96/5452 - What is the meaning of Jesus ? ~ What is # is the meaning of
#  97/5452 - What company 's logo is a `` W '' in a circle ? ~ You # is company logo
#  98/5452 - What is the definition of a cascade ? ~ What is # is the definition of
#  99/5452 - When did Rococo painting and architecture flourish ? ~ When flourish # painting Rococo # flourish Rococo painting and architecture
#  100/5452 - What country 's national passenger rail system is called Via ? ~ You # called Via
#  101/5452 - Who invented Make-up ? ~ Who invented # invented Make - up
#  102/5452 - What is the origin of the word `` attic '' ? ~ What is # is the origin of
#  103/5452 - What did Delilah do to Samson 's hair ? ~ You # do What # do Delilah
#  104/5452 - What kind of animals were in the Paleozoic era ? ~ You
#  105/5452 - Which of the following was Rhodes Scholar ? ~ You # was Which of
#  106/5452 - Who comprised the now-defunct comic book team known as the Champions ? ~ Who comprised # comprised the defunct book team known
#  107/5452 - How do you make a paintball ? ~ How make # make you # make a paintball
#  108/5452 - What U.S. state is Fort Knox in ? ~ What is # is U.S. state
#  109/5452 - What is a female rabbit called ? ~ What is # is a female rabbit called
#  110/5452 - Where is the highest point in Japan ? ~ Where is # is the highest point in
#  111/5452 - Where do chihuahuas come from ? ~ Where come # come chihuahuas
#  112/5452 - Where does Barney Rubble go to work after he drops Fred off in the `` Flintstones '' cartoon series ? ~ Where go # go Barney Rubble # drops he # drops Fred
#  113/5452 - What are the world 's four oceans ? ~ What are # are world four oceans
#  114/5452 - What 's the only work by Michelangelo that bears his signature ? ~ What 's # 's the only work by bears # bears that # bears his signature
#  115/5452 - What is the largest snake in the world ? ~ What is # is the largest snake in
#  116/5452 - In what medium is Stuart Hamblen considered to be the first singing cowboy ? ~ You # considered Stuart Hamblen
#  117/5452 - Where on the Internet can I find a song lyrics database similar to the International Lyrics Server ? ~ Where find # find I # find a song lyrics database similar
#  118/5452 - How much money does a back injury lawsuit get ? ~ How much # does much money # get a injury lawsuit
#  119/5452 - What 's the common name for acetylsalicylic acid ? ~ What 's # 's the common name for
#  120/5452 - What does the Georgetown `` Hoya '' mean ? ~ You # mean What # mean the Georgetown ` ` Hoya
#  121/5452 - Where can I find a list of `` classic '' books 5th and 6th graders should read ? ~ Where find # find I # find a list of # read 5th graders
#  122/5452 - Which two products use a tiger as their symbol ? ~ You # use Which two products # use a tiger as
#  123/5452 - How is the election of a new Pope announced to the world ? ~ How is # announced the election of
#  124/5452 - How long does it take for your blood to make one complete trip through the body ? ~ How long # take it # make your blood # make one complete trip
#  125/5452 - How do chickens have baby chicks ? ~ How have # have chickens # have baby chicks
#  126/5452 - What is the historical relationship of Catholic Church and bingo ? ~ What is # is the historical relationship of
#  127/5452 - How was the element calcium named ? ~ How was # was the element calcium named
#  128/5452 - What crooner joined The Andrews Sisters for Pistol Packin Mama ? ~ You # joined What crooner # joined The Andrews Sisters for
#  129/5452 - What piano company claims its product is the `` Instrument of the immortals '' ? ~ You # claims What piano company # is its product
#  130/5452 - When did the Bounty mutiny take place ? ~ When take # take the Bounty mutiny # take place
#  131/5452 - What novel inspired the movie BladeRunner ? ~ You # inspired What novel # inspired the movie
#  132/5452 - What is a transistor ? ~ What is # is a transistor
#  133/5452 - What is a film starring Jude Law ? ~ What is # is a film starring # starring Jude Law
#  134/5452 - What Hollywood dog died in the arms of Jean Harlow in 1932 ? ~ You # died What # died Hollywood dog
#  135/5452 - What are the most common elements in the Earth 's crust ? ~ What are # are the common elements in
#  136/5452 - How much would it cost to purchase a 2-foot-square party tent , with sides , ? ~ How much # cost How much # cost it # purchase a square party tent
#  137/5452 - What actress has received the most Oscar nominations ? ~ You # received What actress # received the most Oscar nominations
#  138/5452 - What are equity securities ? ~ What are # are equity securities
#  139/5452 - What is gymnophobia ? ~ What is # is gymnophobia
#  140/5452 - How many years do fossils take to form ? ~ How many # take fossils
#  141/5452 - Where is the Orinoco ? ~ Where is # is the Orinoco
#  142/5452 - What was the name of the `` Little Rascals '' dog ? ~ What was # was the name of
#  143/5452 - What city boasts Penn 's Landing , on the banks of the Delaware river ? ~ You # boasts What city # boasts Penn Landing
#  144/5452 - What Broadway musical was inspired by Cervantes 's Don Quixote ? ~ You # inspired What
#  145/5452 - What is the origin of the word , JJ . ~ What is # is the origin of
#  146/5452 - How many hostages were killed in the Entebbe raid ? ~ How many
#  147/5452 - How you can raise your IQ ? ~ How raise # raise you # raise your IQ
#  148/5452 - What does INRI stand for when used on Jesus ' cross ? ~ You # stand INRI
#  149/5452 - Who produces Spumante ? ~ Who produces # produces Spumante
#  150/5452 - Who earns their money the hard way ? ~ Who earns # earns their money
#  151/5452 - Who founded the People 's Temple Commune ? ~ Who founded # founded People Temple Commune
#  152/5452 - What athlete makes the most money from sports merchandise sales ? ~ You # makes What athlete # makes the most money from
#  153/5452 - How many bends are there in a standard paper clip ? ~ How many
#  154/5452 - Who discovered electricity ? ~ Who discovered # discovered electricity
#  155/5452 - What part of your body contains the corpus callosum ? ~ You # contains What part of # contains the corpus callosum
#  156/5452 - Who was the first American in space ? ~ Who was # was the first American in
#  157/5452 - What two South American countries do n't border Brazil ? ~ You # border What # border two American countries # border Brazil
#  158/5452 - What album put The Beatles on the cover of Time in 1967 ? ~ You # put What album # put The Beatles
#  159/5452 - What poem contains the line , `` grow old with me the best is yet to be '' . ~ You # contains What poem # contains the line # is the best
#  160/5452 - What is a dental root canal ? ~ What is # is a dental root canal
#  161/5452 - What war did the Wanna-Go-Home Riots occur after ? ~ You # occur the Wanna - Go - Home Riots
#  162/5452 - What is the busiest air travel season ? ~ What is # is the busiest travel season
#  163/5452 - What 's the colored part of the eye called ? ~ What 's # 's the colored part of called
#  164/5452 - What are hook worms ? ~ What are # are hook worms
#  165/5452 - Where is the Rose Bowl played ? ~ Where is # played the Rose Bowl
#  166/5452 - Which Japanese car maker had its biggest percentage of sale in the domestic market ? ~ You # had Which Japanese car maker # had its biggest percentage of in
#  167/5452 - Who is the mayor of Marbella ? ~ Who is # is the mayor of
#  168/5452 - What sun-blasted , 14-mile wide valley is just north of the Mojave desert ? ~ You # blasted What # is wide valley
#  169/5452 - In what year did Thatcher become prime minister ? ~ You # become Thatcher
#  170/5452 - How many months does it take the moon to revolve around the Earth ? ~ How many # take it # take the moon
#  171/5452 - Where are the 49 steps ? ~ Where are # are the 49 steps
#  172/5452 - In what year was De Gaulle elected president of France ? ~ You # elected De Gaulle # elected president of
#  173/5452 - Who sings the themes for `` Dawson 's Creek '' and `` Felicity '' ? ~ Who sings # sings the themes for and Felicity
#  174/5452 - Who directed `` Jaws '' ? ~ Who directed # directed ` ` Jaws ''
#  175/5452 - On what T.V. show could Tom Terrific be found ? ~ You # show what
#  176/5452 - What Indian tribe is F Troop perpetually doing battle with ? ~ You # is What Indian tribe # doing F Troop # doing battle
#  177/5452 - Where did Indian Pudding come from ? ~ You # come Indian Pudding
#  178/5452 - Why do some clothing labels say `` Use a nonchlorine bleach '' ? ~ Why say # say some clothing labels # Use a nonchlorine bleach
#  179/5452 - How many colonies were involved in the American Revolution ? ~ How many
#  180/5452 - What is the name of the city that Maurizio Pellegrin lives in ? ~ What is # is the name of # lives Maurizio Pellegrin
#  181/5452 - Where can I find pictorial directions on how to build a very simple treehouse ? ~ Where find # find I # find pictorial directions on # build a simple treehouse
#  182/5452 - What game 's board shows the territories of Irkutsk , Yakutsk and Kamchatka ? ~ You # shows game board # shows the territories of
#  183/5452 - What is the name of the managing director of Apricot Computer ? ~ What is # is the name of
#  184/5452 - What is the occupation of Nicholas Cage ? ~ What is # is the occupation of
#  185/5452 - Why do horseshoes bring luck ? ~ Why bring # bring horseshoes # bring luck
#  186/5452 - What is the 401 , K , plan ? ~ What is # is the 401 , K # is , plan
#  187/5452 - What causes pneumonia ? ~ You # causes What # causes pneumonia
#  188/5452 - What are the three winter months in the southern hemisphere ? ~ What are # are the three winter months in
#  189/5452 - What does gringo mean ? ~ You # mean What # mean gringo
#  190/5452 - What country contains Africa 's northernmost point ? ~ You # contains What country # contains Africa northernmost point
#  191/5452 - What therapy attempts to elicit the `` primal scream '' ? ~ You # attempts What therapy # elicit the ` ` primal scream
#  192/5452 - Where is the Kalahari desert ? ~ Where is # is the Kalahari desert
#  193/5452 - Which Ventura County police department seized the largest cocaine shipment in it 's history ? ~ You # seized County police department # seized the largest cocaine shipment in # 's it
#  194/5452 - What city is sometimes called Gotham ? ~ You # called Gotham
#  195/5452 - What dangles over the tongue from the palate ? ~ You
#  196/5452 - Who created Dennis the Menace ? ~ Who created # created Dennis Menace
#  197/5452 - What dummy received an honorary degree from Northwestern University ? ~ You # received What dummy # received an honorary degree
#  198/5452 - When was the first Wall Street Journal published ? ~ When was # published the first Street Journal
#  199/5452 - What countries have the largest areas of forest ? ~ You # have What countries # have the largest areas of
#  200/5452 - How do I start a web based business ? ~ How start # start I # start a based business
#  201/5452 - Name Alvin 's brothers ~ You
#  202/5452 - What is Eagle 's syndrome styloid process ? ~ What is # is Eagle syndrome styloid process
#  203/5452 - How did Jayne Mansfield die ? ~ How die # die Jayne Mansfield
#  204/5452 - When did the royal wedding of Prince Andrew and Fergie take place ? ~ When take # take the royal wedding of # take place
#  205/5452 - What actor said in A Day at the Races : `` Either he 's dead or my watch has stopped '' ? ~ You # said What actor # 's he # stopped my watch
#  206/5452 - What explorer was nicknamed Iberia 's Pilot ? ~ You # nicknamed Iberia Pilot
#  207/5452 - CNN began broadcasting in what year ? ~ You # began CNN
#  208/5452 - What is a ball that hits the foul pole called ? ~ What is # is a ball hits # hits that # hits the foul pole called
#  209/5452 - What makes hamburgers taste like steakburgers ? ~ You # makes What # taste hamburgers
#  210/5452 - Which company created the Internet browser Mosaic ? ~ You # created Which company # created the Internet browser
#  211/5452 - What are the rites accompanying the circumcision of a newly born-child in Judaism called ? ~ What are # are the rites accompanying # accompanying the circumcision of called
#  212/5452 - What was the education system in the 1960 's ? ~ What was # was the education system in
#  213/5452 - What South American city has the world 's highest commercial landing field ? ~ You # has What # has American city # has world highest commercial landing field
#  214/5452 - How can I find out which cities have cable-modem access ? ~ How find # find I # have which cities # have modem access
#  215/5452 - What is Betsy Ross famous for ? ~ What is # is Betsy Ross famous
#  216/5452 - How many species of sharks are there ? ~ How many # are many species of
#  217/5452 - What is `` snoogans '' ? ~ You # is What # is ` ` snoogans ''
#  218/5452 - How many people are there in the world ? ~ How many # are many people
#  219/5452 - What shrubs can be planted that will be safe from deer ? ~ You # be that
#  220/5452 - What organization 's offices were broken into at Watergate in 1972 ? ~ You
#  221/5452 - What is the design of the ship Titanic ? ~ What is # is the design of
#  222/5452 - What does S.O.S. stand for ? ~ You # stand S.O.S.
#  223/5452 - Name a technique widely used to detect birth defects ? ~ You # Name a technique used # detect birth defects
#  224/5452 - What is the daily requirement of folic acid for an expectant mother ? ~ What is # is the daily requirement of for
#  225/5452 - What is the `` 7-minute cigarette '' ? ~ What is # is the ` ` minute cigarette
#  226/5452 - What four forms does gold occur in ? ~ You # does What # does four forms # occur gold
#  227/5452 - What is the acreage of the Chappellet vineyard ? ~ What is # is the acreage of
#  228/5452 - How do you correctly say the word ` qigong ' ? ~ How say # say you # say the word ` qigong
#  229/5452 - When did beethoven die ? ~ When beethoven
#  230/5452 - How much does a new railroad coal car cost ? ~ How much # cost How much # cost a new coal car
#  231/5452 - What two European countries entered the War of American Independence against the British ? ~ You # entered What # entered two European countries # entered the War of
#  232/5452 - What is the filmmakers collabrative ? ~ What is # collabrative the filmmakers
#  233/5452 - What Russian composer 's Prelude in C Sharp Minor brought him fame and fortune ? ~ You # brought What composer Prelude in Minor # brought him # brought fame and fortune
#  234/5452 - What caused Harry Houdini 's death ? ~ You # caused What # caused Houdini death
#  235/5452 - Who was the mother of the man who would not be king , the duke of Windsor ? ~ Who was # was the mother of , duke # be who
#  236/5452 - How many revolutions does a standard LP make in three minutes ? ~ How many # make many revolutions
#  237/5452 - What is the name of the tallest mountain in the world ? ~ What is # is the name of
#  238/5452 - Where can I find a review of Nightmare on Elm Street in a film journal ? ~ Where find # find I # find a review of on
#  239/5452 - What 's the slowest Olympic swimming stroke ? ~ What 's # 's the slowest swimming stroke
#  240/5452 - What was the name of the first Russian astronaut to do a spacewalk ? ~ What was # was the name of do # do a spacewalk
#  241/5452 - What disease is transmitted by the Anopheles mosquito ? ~ You
#  242/5452 - What rum is so `` mixable '' it is a one-brand bar ? ~ You # is What rum # is it
#  243/5452 - How many South American countries have the letter Z in their names ? ~ How many # have many American countries # have the letter Z
#  244/5452 - What is the contents of proposition 98 ? ~ What is # is the contents of
#  245/5452 - Where was George Washington born ? ~ Where born # born George Washington
#  246/5452 - How many people on the ground were killed from the bombing of Pan Am Flight 103 over Lockerbie , Scotland , December 21 , CD . ~ How many
#  247/5452 - Who wrote NN DT NNP NNP '' ? ~ Who wrote # wrote NN DT NNP NNP
#  248/5452 - What is paracetamol ? ~ What is # is paracetamol
#  249/5452 - What are the powers and weaknesses of Green Lantern 's ring ? ~ What are # are the powers and weaknesses of
#  250/5452 - Which mosquito 's bite draws blood , DT NN CC DT NN . ~ You # draws mosquito bite # draws blood
#  251/5452 - When was the first steel mill in the United States built ? ~ When was # built the first steel mill in
#  252/5452 - What diminutive American female gymnast stole the show at the 1984 Olympics ? ~ You # stole What diminutive American female gymnast # stole the show
#  253/5452 - What is the origin of the name Katie ? ~ What is # is the origin of Katie
#  254/5452 - What schools in the Washington , DC NN NN VBP NN NN NN NN . ~ You
#  255/5452 - When did the Berlin Wall go up ? ~ When go # go the Berlin Wall
#  256/5452 - Who is Terrence Malick ? ~ Who is # is Terrence Malick
#  257/5452 - What instrument is Ray Charles best known for playing ? ~ You
#  258/5452 - What 's the meaning of the Latin battle cry : Ad arma , ad arma . ~ What 's # 's the meaning of # 's Ad arma , arma
#  259/5452 - What is the mascot for Notre Dame University ? ~ What is # is the mascot for
#  260/5452 - What Las Vegas hotel burned in November , 1980 , with the loss of 84 lives ? ~ You # burned What # burned Vegas hotel
#  261/5452 - When did Mount St. Helen last have a significant eruption ? ~ When have # have Mount St. Helen # have a significant eruption
#  262/5452 - CNN is the abbreviation for what ? ~ You # is CNN
#  263/5452 - When did World War I start ? ~ When start # did World War # start I
#  264/5452 - How many feet are there in a fathom ? ~ How many # are many feet
#  265/5452 - What is a Canada two-penny black ? ~ What is # is a Canada penny black
#  266/5452 - What European city do Nicois live in ? ~ You # live Nicois
#  267/5452 - How can I find out what year a Beanie Baby was introduced ? ~ How find # find I
#  268/5452 - What is the classic definition of tragic hero ? ~ What is # is the classic definition of
#  269/5452 - To what does Microsoft 's Windows 3 owe its success ? ~ You # owe what # owe Microsoft Windows 3 # owe its success
#  270/5452 - Who was President of Afghanistan in 1994 ? ~ Who was
#  271/5452 - What are other ways of getting stretch marks besides pregnancy , weight loss , and weight lifting ? ~ What are # are other ways of # getting stretch marks
#  272/5452 - What did brontosauruses eat ? ~ You # eat What # eat brontosauruses
#  273/5452 - What color bottles do good Rhine wines come in ? ~ You # do What color bottles # do good Rhine wines
#  274/5452 - Who was the lead actress in the movie ` Sleepless in Seattle ' ? ~ Who was # was the lead actress in ` Sleepless
#  275/5452 - Who was the 16th President of the United States ? ~ Who was
#  276/5452 - Who are the two sons of Ozzie and Harriet Nelson ? ~ Who are # are the two sons of
#  277/5452 - What is molybdenum ? ~ What is # is molybdenum
#  278/5452 - When is Boxing Day ? ~ When Boxing # Boxing Day
#  279/5452 - What is the lowest level of the American judiciary ? ~ What is # is the lowest level of
#  280/5452 - When was the battle of the Somme fought ? ~ When was # fought the battle of
#  281/5452 - How many people did Randy Craft kill ? ~ How many # did many people # kill Randy Craft
#  282/5452 - What 's the official animal of Canada ? ~ What 's # 's the official animal of
#  283/5452 - When did Spielberg direct `` Jaws '' ? ~ When direct # direct Spielberg
#  284/5452 - What is the size of the largest akita ? ~ What is # is the size of
#  285/5452 - What animal has the biggest eyes ? ~ You # has What animal # has the biggest eyes
#  286/5452 - What is California 's capital ? ~ What is # is California capital
#  287/5452 - Who was the author of the book about computer hackers called `` The Cuckoo 's Egg : Tracking a Spy Through the Maze of Computer Espionage '' ? ~ Who was # was the author of # called Cuckoo Egg : Tracking '' # Tracking a Spy
#  288/5452 - Who was the founding member of the Pink Floyd band ? ~ Who was # was the founding member of
#  289/5452 - What European country is home to the beer-producing city of Budweis ? ~ You # is What European country
#  290/5452 - How do I find the balance of my social security account ? ~ How find # find I # find the balance of
#  291/5452 - What is the history of Valentine 's Day cards ? ~ What is # is the history of
#  292/5452 - Where was Christopher Columbus born ? ~ Where born # born Christopher Columbus
#  293/5452 - What do Italians call Florence ? ~ You # call What # call Italians # call Florence
#  294/5452 - How do you get to the top of the Eiffel Tower ? ~ How get # get you
#  295/5452 - What does ` PSI ' stand for ? ~ You # PSI What
#  296/5452 - What sea did the Romans call mare nostrum ? ~ You # call What sea # call the Romans # call mare # call nostrum
#  297/5452 - What 's the term for a bet before cards are dealt ? ~ What 's # 's the term for
#  298/5452 - Which came first , according to Genesis 1 : 2 : 22 - the chicken or the egg ? ~ You # came Which
#  299/5452 - What city did the Flintstones live in ? ~ You # live the Flintstones
#  300/5452 - What is Latin for incompetent ? ~ What is # is Latin
#  301/5452 - What chemicals are used in lethal injection ? ~ You
#  302/5452 - What toy company is the world 's No.1 maker of female apparel ? ~ You # is What toy company
#  303/5452 - What board game does a `` wood-pusher '' play poorly ? ~ You # does What board game # play a ` ` wood - pusher # does pusher '' play poorly ?
#  304/5452 - Which Doonesbury character was likely to turn into a werewolf ? ~ You # was Which Doonesbury character
#  305/5452 - What is the abbreviation for micro ? ~ What is # is the abbreviation for
#  306/5452 - What are the 7 articles of the constitution ? ~ What are # are the 7 articles of
#  307/5452 - Who has won the most Super Bowls ? ~ Who won # won the most Super Bowls
#  308/5452 - What does NASDAQ stand for ? ~ You # stand NASDAQ
#  309/5452 - What is BPH ? ~ What is # is BPH
#  310/5452 - What is the fastest commercial automobile that can be bought in the US ? ~ What is # is the fastest commercial automobile bought
#  311/5452 - What stadium do the Miami Dolphins play their home games in ? ~ You # play What stadium # play the Miami Dolphins # play their home games
#  312/5452 - Who has the only speaking role in `` Silent Movie '' ? ~ Who has # has the only speaking role in ''
#  313/5452 - Why is poop sometimes different colors ? ~ Why is # is poop # is different colors
#  314/5452 - What was Einstein 's IQ ? ~ What was # was Einstein IQ
#  315/5452 - What day was Pearl Harbor attacked in 1942 ? ~ You # attacked Pearl Harbor
#  316/5452 - What girl 's name is `` Teddy '' an affectionate form of ? ~ You # is girl name
#  317/5452 - What state is John F. Kennedy buried in ? ~ You # buried John F. Kennedy
#  318/5452 - What is the best way to remove wallpaper ? ~ What is # is the best way remove # remove wallpaper
#  319/5452 - What U.S. state has an element named for it ? ~ You # has What # has U.S. state # has an element named
#  320/5452 - What company tabulates the ballots in voting for the Academy Awards ? ~ You # tabulates What company # tabulates the ballots
#  321/5452 - How did the tradition of best man start ? ~ How start # start the tradition of
#  322/5452 - How many years ago did the ship Titanic sink ? ~ How many # sink the ship
#  323/5452 - What is the deepest area of the Arctic Ocean ? ~ What is # is the deepest area of
#  324/5452 - What are Halloween 's colors ? ~ What are # are Halloween colors
#  325/5452 - How is silk screening done ? ~ How done
#  326/5452 - What is the latitude and longitude of El Paso , Texas ? ~ What is # is the latitude and longitude of
#  327/5452 - Who made a boat out of gopher wood ? ~ Who made # made a boat
#  328/5452 - Where can I find a `` Fifth Element '' screensaver ? ~ Where find # find I # find Element screensaver
#  329/5452 - Which Bloom County resident wreaks havoc with a computer ? ~ You # wreaks Which County resident # wreaks havoc
#  330/5452 - How do you match a name to a social security number ? ~ How match # match you # match a name
#  331/5452 - How does a rainbow form ? ~ How form # form a rainbow
#  332/5452 - What is the normal resting heart rate of a healthy adult ? ~ What is # is the normal resting heart rate of
#  333/5452 - What is the population of Ohio ? ~ What is # is the population of
#  334/5452 - How many calories are there in a Big Mac ? ~ How many # are many calories
#  335/5452 - Hazmat stands for what ? ~ You # stands Hazmat
#  336/5452 - What creature scares people in the film `` Jaws '' ? ~ You # scares What creature # scares people in Jaws
#  337/5452 - What part did John Peter Zenger play in the deveopment of the newspaper in America ? ~ You # play What part # play John Peter Zenger
#  338/5452 - Who followed Caesar ? ~ Who followed # followed Caesar
#  339/5452 - What are the four elements ? ~ What are # are the four elements
#  340/5452 - Who was the first woman golfer to earn a million ? ~ Who was # earn a million
#  341/5452 - What 's the tallest piece on a chessboard ? ~ What 's # 's the tallest piece on
#  342/5452 - What is Answers.com 's address ? ~ What is # is Answers.com address
#  343/5452 - Where can I buy movies on videotape online ? ~ Where buy # buy I # buy movies
#  344/5452 - Who does the advertizing for Frito-Lay ? ~ Who does # does the advertizing for
#  345/5452 - Who is the leading competitor of Trans Union Company ? ~ Who is # is the leading competitor of
#  346/5452 - What product did Robert Conrad dare people to knock off his shoulder ? ~ You # dare What product # dare Robert Conrad # dare people # knock his shoulder
#  347/5452 - Who invented the radio ? ~ Who invented # invented the radio
#  348/5452 - What 's the American dollar equivalent for 8 pounds in the U.K. ? ~ What 's # equivalent the American dollar
#  349/5452 - What are the different approaches of systems analysis ? ~ What are # are the different approaches of
#  350/5452 - How do doctors diagnose bone cancer ? ~ How diagnose # diagnose doctors # diagnose bone cancer
#  351/5452 - Who is the man behind the pig-the man who pulls the strings and speaks for Miss Piggy ? ~ Who is # is the man behind # pulls who # pulls the strings
#  352/5452 - What is the speed of the Mississippi River ? ~ What is # is the speed of
#  353/5452 - What are the developmental stages of a swimmer ? ~ What are # are the developmental stages of
#  354/5452 - What actor first portrayed James Bond ? ~ You # portrayed What actor # portrayed James Bond
#  355/5452 - What ocean is the largest in the world ? ~ You
#  356/5452 - Who was the first American poet to win the Nobel Prize for literature , in 1948 ? ~ Who was # win the Nobel Prize for
#  357/5452 - What year did Jack Nicklaus join the Professional Golfers Association tour ? ~ You # join Jack Nicklaus # join the Association tour
#  358/5452 - How many sonnets did Shakespeare write ? ~ How many # did many sonnets # write Shakespeare
#  359/5452 - What causes the redness in your cheeks when you blush ? ~ You # causes What # causes the redness # blush you
#  360/5452 - Who won the Nobel Peace Prize in 1991 ? ~ Who won # won the Nobel Peace Prize
#  361/5452 - Who are the Challengers of the Unknown ? ~ Who are
#  362/5452 - Define the Pheonix Club ? ~ You # Define the Pheonix Club
#  363/5452 - Which city did Christian Crusaders fight to recapture from the Muslims ? ~ You # did Which city # fight Christian Crusaders
#  364/5452 - What does it mean `` Rupee Depreciates '' ? ~ You # mean What # mean it # mean Rupee Depreciates
#  365/5452 - What gaming devices were dubbed `` Mississippi marbles '' and `` Memphis dominoes '' ? ~ You # dubbed ` ` Mississippi marbles ''
#  366/5452 - Who was the first coach of the Cleveland Browns ? ~ Who was # was the first coach of
#  367/5452 - How successful is arometherapy ? ~ How successful
#  368/5452 - What Jewish holiday saw the start of the 1973 Mideast War ? ~ You # saw What Jewish holiday # saw the start of
#  369/5452 - How does a copier work ? ~ How work
#  370/5452 - What is the speed of the Mississippi River ? ~ What is # is the speed of
#  371/5452 - Who said of Super Bowl III in 1969 : `` We 'll win- I guarantee it '' ? ~ Who guarantee # 'll We # guarantee I # guarantee it III
#  372/5452 - What is Dudley Do-Right 's horse 's name ? ~ What is # is horse name
#  373/5452 - Who declared : `` I am down on whores and I shan 't stop ripping them '' ? ~ Who declared # am I # shan I # stop t # ripping them
#  374/5452 - Where does chocolate come from ? ~ You # come chocolate
#  375/5452 - What TV game show once saw a contestant admit to picking his toes in the shower ? ~ You # saw What game show # admit a contestant # saw contestant admit to # picking his toes
#  376/5452 - What Soviet leader owned a Rolls-Royce ? ~ You # owned What # owned Soviet leader # owned a Rolls - Royce
#  377/5452 - Where can I find a case on Individuals with Disabilities Education Act of 1991 ? ~ Where find # find I # find a case
#  378/5452 - What war did Florence Nightingale tend the troops in ? ~ You # tend What war # tend Florence Nightingale # tend the troops
#  379/5452 - Who wrote the song , `` Stardust '' ? ~ Who wrote # wrote the song , ` ` Stardust ''
#  380/5452 - How many Beatles ' records went #1 ? ~ How many # went Beatles records
#  381/5452 - Who is the only prime minister of Canada to serve 22 years but not necessarily consecutively ? ~ Who is # is the only prime minister of serve but # serve 22 years
#  382/5452 - What is the abbreviation of the company name ` General Motors ' ? ~ What is # is the abbreviation of
#  383/5452 - What mountains lie between the Arkansas and Missouri rivers ? ~ You # lie What mountains
#  384/5452 - Who received the Will Rogers Award in 1989 ? ~ Who received # received the Will Rogers Award
#  385/5452 - What is the function of RAM ? ~ What is # is the function of
#  386/5452 - What 's the closest G2 Spectrum Yellow Dwarf to Earth ? ~ What 's # 's the closest G2 Spectrum Yellow Dwarf to
#  387/5452 - How many equal angles are there in an isosceles triangle ? ~ How many # are many equal angles
#  388/5452 - What is the fear of cockroaches called ? ~ What is # is the fear of
#  389/5452 - What CBS soap opera was interrupted by the bulletin of John F. Kennedy 's assassination ? ~ You # interrupted What
#  390/5452 - What is the use of a 24-hour clock instead of a 12-hour clock ? ~ What is # is the use of of # is a hour clock
#  391/5452 - What was the name of the lawyer who represented Randy Craft ? ~ What was # was the name of # represented who # represented Randy Craft
#  392/5452 - What United States President had dreamed that he was assassinated ? ~ You # dreamed What # dreamed States President
#  393/5452 - What film did Lee Marvin win the 1965 best actor Oscar for ? ~ You # win What film # win Lee Marvin # win the 1965 best actor Oscar
#  394/5452 - Where is Basque country located ? ~ Where is # located Basque country
#  395/5452 - What product does `` Mrs. Olsen '' promote ? ~ You # Olsen What product # promote product does ` ` Mrs. Olsen
#  396/5452 - What time of day did Emperor Hirohito die ? ~ You # did What time of # die Emperor Hirohito
#  397/5452 - What is dry ice ? ~ You # is What # is dry ice
#  398/5452 - What 's the most powerful card in Euchre ? ~ What 's # 's the powerful card in
#  399/5452 - What does `` intractable plantar keratoma '' mean ? ~ You # mean What keratoma
#  400/5452 - How many years did it take James Joyce to write Ulysses ? ~ How many # take it # take James Joyce # write Ulysses
#  401/5452 - What crop failure caused the Irish Famine ? ~ You # caused What crop failure # caused the Irish Famine
#  402/5452 - What South Korean city is served by Kimpo International Airport ? ~ You # served What
#  403/5452 - How many types of dogs ' tails are there - three ~ How many # are many types of
#  404/5452 - What is the longest-running television series ? ~ What is # is the running television series
#  405/5452 - What predators exist on Antarctica ? ~ You # exist What # exist predators
#  406/5452 - What is the difference between a generator and an alternator ? ~ What is # is the difference between
#  407/5452 - How is energy created ? ~ How created
#  408/5452 - What beer advertised that it had `` three rings '' ? ~ You # advertised What beer # had it # had ` three rings
#  409/5452 - What is the quantity of American soldiers still unaccounted for from the Vietnam war ? ~ What is # unaccounted the quantity of
#  410/5452 - What golfing accessory was patented by George Grant on December 12 ~ You
#  411/5452 - What are the different types of plastic ? ~ What are # are the different types of
#  412/5452 - How is it correct to say ` qigong ' ? ~ How is # is it
#  413/5452 - What was the highest mountain on earth before Mount Everest was discovered ? ~ What was # was the highest mountain on
#  414/5452 - Where was the Ligurian Republic , 1797-185 , ? ~ Where was # was the Ligurian Republic , 1797 ,
#  415/5452 - What country 's people are the top television watchers ? ~ You # are country people
#  416/5452 - When was the women 's suffrage amendment ratified ? ~ When was # ratified women suffrage amendment
#  417/5452 - What Polynesian people inhabit New Zealand ? ~ You # inhabit What # inhabit Polynesian people # inhabit New Zealand
#  418/5452 - What movie tour of the Roman empire features the admonition : `` Row well and live '' ? ~ You # features What movie tour of # features the admonition # features Row well ''
#  419/5452 - What Nevada center has been dubbed The Biggest Little City in the World ? ~ You # dubbed What # dubbed The Biggest Little City in
#  420/5452 - What President lived at 219 North Delaware Street , Independence , Missouri ? ~ You # lived What # lived President
#  421/5452 - Give a reason for American Indians oftentimes dropping out of school . ~ You # Give a reason oftentimes
#  422/5452 - Where must a soccer goalie stand to be permitted to handle the ball ? ~ Where stand # stand a soccer goalie # handle the ball
#  423/5452 - What is the difference between classical conditioning and operant conditioning ? ~ What is # is the difference between
#  424/5452 - In what U.S. state was the first woman governor elected ? ~ You # was U.S. state
#  425/5452 - What are some interesting facts and information about dogsledding ? ~ What are # are some interesting facts and information about
#  426/5452 - What year did Hitler die ? ~ You # die Hitler
#  427/5452 - What famous model was married to Billy Joel ? ~ You # was What famous model
#  428/5452 - What kind of animal is Babar ? ~ You
#  429/5452 - What is Jane Goodall known for ? ~ What is # known Jane Goodall
#  430/5452 - What killed Bob Marley ? ~ You # killed What # killed Bob Marley
#  431/5452 - How much money are Dumbo 's ears insured for ? ~ How much # are much money # insured Dumbo ears
#  432/5452 - Who danced into stardom with Fred Astaire in 1941 's You 'll Never Get Rich ? ~ Who danced # Get You
#  433/5452 - Who is Stein Eriksen ? ~ Who is # is Stein Eriksen
#  434/5452 - What does the name Billie mean ? ~ You # mean What # mean the name Billie
#  435/5452 - Who is the fastest swimmer in the world ? ~ Who is # is the fastest swimmer in
#  436/5452 - What is the highest peak in Africa ? ~ What is # is the highest peak in
#  437/5452 - Where is Procter & Gamble headquartered in the U.S. ? ~ Where is # headquartered Procter & Gamble
#  438/5452 - What desert has been called The Garden of Allah ? ~ You # called The Garden of
#  439/5452 - What do bicornate animals have two of ? ~ You # have What # have bicornate animals # have two of
#  440/5452 - What function does a community 's water tower serve ? ~ You # serve What function # serve community water tower
#  441/5452 - What is a fear of weakness ? ~ What is # is a fear of
#  442/5452 - How many miles is it to Ohio from North Carolina ? ~ How many # is it
#  443/5452 - How much snow equals an inch of rain ? ~ How much # equals much snow # equals an inch of
#  444/5452 - What does G.M.T. stand for ? ~ You # stand G.M.T.
#  445/5452 - What does Inuit and Eskimo mean ? ~ You # mean What # mean Inuit and Eskimo
#  446/5452 - What song served as the closing theme of The Johnny Cash Show ? ~ You # served What song
#  447/5452 - What field sport did dentist William Beers promote and write a standard book of rules for ? ~ You # dentist What field sport # dentist William Beers # dentist promote and write # write a standard book of
#  448/5452 - How do I tie dye clothes ? ~ How tie # tie I # tie dye clothes
#  449/5452 - When does the average teenager first have intercourse ? ~ When have # have the average teenager
#  450/5452 - Why doesn 't www.answers.com have any answers to my questions ? ~ Why have # have doesn ' t # have any answers to
#  451/5452 - What actor 's autobiography is titled All My Yesterdays ? ~ You # titled All My Yesterdays
#  452/5452 - What Russian master spy lived in the U.S. under the name Emil Goldfus ? ~ You # lived What master spy
#  453/5452 - Where 's the 19th hole on a golf course ? ~ Where 's # 's the 19th hole on
#  454/5452 - What 's nature 's purpose for tornadoes ? ~ What 's # 's nature purpose for
#  455/5452 - Who played the original Charlie 's Angels ? ~ Who played # played the original Charlie Angels
#  456/5452 - Where can I find a person 's address from a telephone number ? ~ Where find # find I # find person address
#  457/5452 - What English word comes from the Old French covrefeu , meaning cover fire ? ~ You # comes English word # meaning cover fire
#  458/5452 - What musical instrument did Prewitt play in James Jones 's From Here to Eternity ? ~ You # play What musical instrument # play Prewitt
#  459/5452 - Where did Sarge Steel get his metal hand ? ~ Where get # get Sarge Steel # get his metal hand
#  460/5452 - What makes popcorn pop ? ~ You # makes What # pop popcorn
#  461/5452 - Who wrote The Night of the Iguana ? ~ Who wrote # wrote The Night of
#  462/5452 - Where does your hair grow the fastest ? ~ Where grow # grow your hair
#  463/5452 - What country did King Gustav V reign over from 197 to 195 ? ~ You # did What country # did V reign
#  464/5452 - Who painted Mother and Child ? ~ Who painted # painted Mother and Child
#  465/5452 - What is the speed of the Mississippi River ? ~ What is # is the speed of
#  466/5452 - In what area of the world was the Six Day War fought ? ~ You # was what area of # fought the Day War
#  467/5452 - What is the brightest star visible from Earth ? ~ What is # is the brightest star visible
#  468/5452 - What film marked Robert Redford 's directorial debut ? ~ You # marked What film # marked Redford directorial debut
#  469/5452 - What was Mao 's second name ? ~ What was # was Mao second name
#  470/5452 - What film or films has Jude Law appeared in ? ~ You # has What film or films # appeared Jude Law
#  471/5452 - Where do hyenas live ? ~ Where live # live hyenas
#  472/5452 - Who is the `` Queen Mother '' ? ~ Who is # is the ` ` Queen Mother ''
#  473/5452 - What 's the most commonly-spoken language in Belgium ? ~ What 's # 's the spoken language in
#  474/5452 - Who has more DNA - a man or a woman ? ~ Who has # has more DNA - man
#  475/5452 - What are Maid-Rites ? ~ What are
# ...
#  304/500 - What date did Neil Armstrong land on the moon ? ~ You # did What date # did Armstrong land on
#  305/500 - When was Hiroshima bombed ? ~ When bombed # bombed Hiroshima
#  306/500 - Where is the Savannah River ? ~ Where is # is the Savannah River
#  307/500 - Who was the first woman killed in the Vietnam War ? ~ Who was # was the first woman killed
#  308/500 - What planet has the strongest magnetic field of all the planets ? ~ You # has What planet # has the strongest magnetic field of
#  309/500 - Who is the governor of Alaska ? ~ Who is # is the governor of
#  310/500 - What year did Mussolini seize power in Italy ? ~ You # seize Mussolini # seize power
#  311/500 - What is the capital of Persia ? ~ What is # is the capital of
#  312/500 - Where is the Eiffel Tower ? ~ Where is # is the Eiffel Tower
#  313/500 - How many hearts does an octopus have ? ~ How many # have many hearts # have an octopus
#  314/500 - What is pneumonia ? ~ What is # is pneumonia
#  315/500 - What is the deepest lake in the US ? ~ What is # is the deepest lake in
#  316/500 - What is a fuel cell ? ~ What is # is a fuel cell
#  317/500 - Who was the first U.S. president to appear on TV ? ~ Who was # was the first U.S. president appear
#  318/500 - Where is the Little League Museum ? ~ Where is # is the League Museum
#  319/500 - What are the two types of twins ? ~ What are # are the two types of
#  320/500 - What is the brightest star ? ~ What is # is the brightest star
#  321/500 - What is diabetes ? ~ What is # is diabetes
#  322/500 - When was President Kennedy shot ? ~ When was # shot President Kennedy
#  323/500 - What is TMJ ? ~ What is # is TMJ
#  324/500 - What color is yak milk ? ~ You
#  325/500 - What date was Dwight D. Eisenhower born ? ~ You # born Dwight D. Eisenhower
#  326/500 - What does the technical term ISDN mean ? ~ You # mean What # mean the technical term # mean ISDN
#  327/500 - Why is the sun yellow ? ~ Why is
#  328/500 - What is the conversion rate between dollars and pounds ? ~ What is # is the conversion rate between
#  329/500 - When was Abraham Lincoln born ? ~ When was # born Abraham Lincoln
#  330/500 - What is the Milky Way ? ~ What is # is the Milky Way
#  331/500 - What is mold ? ~ What is # is mold
#  332/500 - What year was Mozart born ? ~ You # born Mozart
#  333/500 - What is a group of frogs called ? ~ What is # is a group of
#  334/500 - What is the name of William Penn 's ship ? ~ What is # is the name of
#  335/500 - What is the melting point of gold ? ~ What is # is the melting point of
#  336/500 - What is the street address of the White House ? ~ What is # is the street address of
#  337/500 - What is semolina ? ~ What is # is semolina
#  338/500 - What fruit is Melba sauce made from ? ~ You
#  339/500 - What is Ursa Major ? ~ What is # is Ursa Major
#  340/500 - What is the percentage of water content in the human body ? ~ What is # is the percentage of
#  341/500 - How much does water weigh ? ~ How much # weigh water
#  342/500 - What was President Lyndon Johnson 's reform program called ? ~ What was # called Johnson reform program
#  343/500 - What is the murder rate in Windsor , Ontario ? ~ What is # is the murder rate in
#  344/500 - Who is the only president to serve 2 non-consecutive terms ? ~ Who is # serve 2 non - consecutive terms
#  345/500 - What is the population of Australia ? ~ What is # is the population of
#  346/500 - Who painted the ceiling of the Sistine Chapel ? ~ Who painted # painted the ceiling of
#  347/500 - Name a stimulant . ~ You # Name a stimulant
#  348/500 - What is the effect of volcanoes on the climate ? ~ What is # is the effect of
#  349/500 - What year did the Andy Griffith show begin ? ~ You # show What year # show the Andy Griffith
#  350/500 - What is acid rain ? ~ What is # is acid rain
#  351/500 - What is the date of Mexico 's independence ? ~ What is # is the date of
#  352/500 - What is the location of Lake Champlain ? ~ What is # is the location of
#  353/500 - What is the Illinois state flower ? ~ What is # is the Illinois state flower
#  354/500 - What is Maryland 's state bird ? ~ What is # is Maryland state bird
#  355/500 - What is quicksilver ? ~ What is
#  356/500 - Who wrote `` The Divine Comedy '' ? ~ Who wrote # wrote The Divine Comedy ''
#  357/500 - What is the speed of light ? ~ What is # is the speed of
#  358/500 - What is the width of a football field ? ~ What is # is the width of
#  359/500 - Why in tennis are zero points called love ? ~ Why are # called love
#  360/500 - What kind of dog was Toto in the Wizard of Oz ? ~ You
#  361/500 - What is a thyroid ? ~ What is # is a thyroid
#  362/500 - What does ciao mean ? ~ You # mean What # mean ciao
#  363/500 - What is the only artery that carries blue blood from the heart to the lungs ? ~ What is # is the only artery carries # carries that # carries blue blood
#  364/500 - How often does Old Faithful erupt at Yellowstone National Park ? ~ How often # does Faithful erupt at
#  365/500 - What is acetic acid ? ~ You # is What # is acetic acid
#  366/500 - What is the elevation of St. Louis , MO ? ~ What is # is the elevation of
#  367/500 - What color does litmus paper turn when it comes into contact with a strong acid ? ~ You # turn What color # comes it
#  368/500 - What are the colors of the German flag ? ~ What are # are the colors of
#  369/500 - What is the Moulin Rouge ? ~ What is # is the Moulin Rouge
#  370/500 - What soviet seaport is on the Black Sea ? ~ You # is What soviet seaport
#  371/500 - What is the atomic weight of silver ? ~ What is # is the atomic weight of
#  372/500 - What currency do they use in Brazil ? ~ You # use What currency # use they
#  373/500 - What are pathogens ? ~ What are # are pathogens
#  374/500 - What is mad cow disease ? ~ What is # is mad cow disease
#  375/500 - Name a food high in zinc . ~ You # Name a food high
#  376/500 - When did North Carolina enter the union ? ~ When enter # enter North Carolina # enter the union
#  377/500 - Where do apple snails live ? ~ Where live # live apple snails
#  378/500 - What are ethics ? ~ What are # are ethics
#  379/500 - What does CPR stand for ? ~ You # stand CPR
#  380/500 - What is an annuity ? ~ What is # is an annuity
#  381/500 - Who killed John F. Kennedy ? ~ Who killed # killed John F. Kennedy
#  382/500 - Who was the first vice president of the U.S. ? ~ Who was
#  383/500 - What birthstone is turquoise ? ~ You
#  384/500 - Who was the first US President to ride in an automobile to his inauguration ? ~ Who was # was the first US President ride
#  385/500 - How old was the youngest president of the United States ? ~ How old
#  386/500 - When was Ulysses S. Grant born ? ~ When was # born Ulysses S. Grant
#  387/500 - What is Muscular Dystrophy ? ~ What is # is Muscular Dystrophy
#  388/500 - Who lived in the Neuschwanstein castle ? ~ Who lived
#  389/500 - What is propylene glycol ? ~ What is # is propylene glycol
#  390/500 - What is a panic disorder ? ~ What is # is a panic disorder
#  391/500 - Who invented the instant Polaroid camera ? ~ Who invented # invented the instant Polaroid camera
#  392/500 - What is a carcinogen ? ~ What is # is a carcinogen
#  393/500 - What is a baby lion called ? ~ What is # is a baby lion called
#  394/500 - What is the world 's population ? ~ What is # is world population
#  395/500 - What is nepotism ? ~ What is # is nepotism
#  396/500 - What is die-casting ? ~ You # is What
#  397/500 - What is myopia ? ~ What is # is myopia
#  398/500 - What is the sales tax rate in New York ? ~ What is # is the tax rate in
#  399/500 - Developing nations comprise what percentage of the world 's population ? ~ You # comprise Developing nations # comprise what percentage of
#  400/500 - What is the fourth highest mountain in the world ? ~ What is # is the highest mountain in
#  401/500 - What is Shakespeare 's nickname ? ~ What is # is Shakespeare nickname
#  402/500 - What is the heaviest naturally occurring element ? ~ What is # is the heaviest occurring # occurring element
#  403/500 - When is Father 's Day ? ~ When is # is Father Day
#  404/500 - What does the acronym NASA stand for ? ~ You # stand the acronym # stand NASA
#  405/500 - How long is the Columbia River in miles ? ~ How long # is the Columbia River in
#  406/500 - What city 's newspaper is called `` The Star '' ? ~ You # called ` The Star ''
#  407/500 - What is carbon dioxide ? ~ What is # is carbon dioxide
#  408/500 - Where is the Mason/Dixon line ? ~ Where is # is the Dixon line
#  409/500 - When was the Boston tea party ? ~ When was # was the Boston tea party
#  410/500 - What is metabolism ? ~ What is # is metabolism
#  411/500 - Which U.S.A. president appeared on `` Laugh-In '' ? ~ You # appeared Which U.S.A. president # appeared Laugh - In
#  412/500 - What are cigarettes made of ? ~ What are # are cigarettes made
#  413/500 - What is the capital of Zimbabwe ? ~ What is # is the capital of
#  414/500 - What does NASA stand for ? ~ You # stand NASA
#  415/500 - What is the state flower of Michigan ? ~ What is # is the state flower of
#  416/500 - What are semiconductors ? ~ What are # are semiconductors
#  417/500 - What is nuclear power ? ~ What is # is nuclear power
#  418/500 - What is a tsunami ? ~ What is # is a tsunami
#  419/500 - Who is the congressman from state of Texas on the armed forces committee ? ~ Who is # is the congressman from on
#  420/500 - Who was president in 1913 ? ~ Who was
#  421/500 - When was the first kidney transplant ? ~ When was # was the first kidney transplant
#  422/500 - What are Canada 's two territories ? ~ What are # are Canada two territories
#  423/500 - What was the name of the plane Lindbergh flew solo across the Atlantic ? ~ What was # was the name of # flew Lindbergh
#  424/500 - What is genocide ? ~ What is
#  425/500 - What continent is Argentina on ? ~ You
#  426/500 - What monastery was raided by Vikings in the late eighth century ? ~ You
#  427/500 - What is an earthquake ? ~ What is # is an earthquake
#  428/500 - Where is the tallest roller coaster located ? ~ Where is # located the tallest roller coaster
#  429/500 - What are enzymes ? ~ What are # are enzymes
#  430/500 - Who discovered oxygen ? ~ Who discovered # discovered oxygen
#  431/500 - What is bangers and mash ? ~ What is # is bangers and mash
#  432/500 - What is the name given to the Tiger at Louisiana State University ? ~ What is # is the name given # given to Tiger
#  433/500 - Where are the British crown jewels kept ? ~ Where are # kept the British crown jewels
#  434/500 - Who was the first person to reach the North Pole ? ~ Who was # was the first person reach # reach the North Pole
#  435/500 - What is an ulcer ? ~ What is # is an ulcer
#  436/500 - What is vertigo ? ~ What is
#  437/500 - What is the spirometer test ? ~ What is # is the spirometer test
#  438/500 - When is the official first day of summer ? ~ When is # is the official first day of
#  439/500 - What does the abbreviation SOS mean ? ~ You # mean What # mean the abbreviation # mean SOS
#  440/500 - What is the smallest bird in Britain ? ~ What is # is the smallest bird in
#  441/500 - Who invented Trivial Pursuit ? ~ Who invented # invented Trivial Pursuit
#  442/500 - What gasses are in the troposphere ? ~ You
#  443/500 - Which country has the most water pollution ? ~ You # has Which country # has the most water pollution
#  444/500 - What is the scientific name for elephant ? ~ What is # is the scientific name for
#  445/500 - Who is the actress known for her role in the movie `` Gypsy '' ? ~ Who is # is the actress known Gypsy
#  446/500 - What breed of hunting dog did the Beverly Hillbillies own ? ~ You # hunting dog # own the Beverly Hillbillies
#  447/500 - What is the rainiest place on Earth ? ~ What is # is the rainiest place on
#  448/500 - Who was the first African American to win the Nobel Prize in literature ? ~ Who was # was the first African American # win the Nobel Prize in
#  449/500 - When is St. Patrick 's Day ? ~ When is # is Patrick Day
#  450/500 - What was FDR 's dog 's name ? ~ What was # was dog name
#  451/500 - What colors need to be mixed to get the color pink ? ~ You # be What # need colors # pink the color
#  452/500 - What is the most popular sport in Japan ? ~ What is # is the popular sport in
#  453/500 - What is the active ingredient in baking soda ? ~ What is # is the active ingredient in # baking soda
#  454/500 - When was Thomas Jefferson born ? ~ When was # born Thomas Jefferson
#  455/500 - How cold should a refrigerator be ? ~ How cold # be a refrigerator
#  456/500 - When was the telephone invented ? ~ When invented
#  457/500 - What is the most common eye color ? ~ What is # is the common eye color
#  458/500 - Where was the first golf course in the United States ? ~ Where was # was the first golf course in
#  459/500 - What is schizophrenia ? ~ What is # is schizophrenia
#  460/500 - What is angiotensin ? ~ What is # is angiotensin
#  461/500 - What did Jesse Jackson organize ? ~ You # organize What # organize Jesse Jackson
#  462/500 - What is New York 's state bird ? ~ What is # is York state bird
#  463/500 - What is the National Park in Utah ? ~ What is # is the National Park in
#  464/500 - What is Susan B. Anthony 's birthday ? ~ What is # is Anthony birthday
#  465/500 - In which state would you find the Catskill Mountains ? ~ You # find you # find the Catskill Mountains
#  466/500 - What do you call a word that is spelled the same backwards and forwards ? ~ You # call What # call you # call a word spelled # spelled the same
#  467/500 - What are pediatricians ? ~ What are # are pediatricians
#  468/500 - What chain store is headquartered in Bentonville , Arkansas ? ~ You
#  469/500 - What are solar cells ? ~ What are # are solar cells
#  470/500 - What is compounded interest ? ~ You # compounded interest
#  471/500 - What are capers ? ~ What are # are capers
#  472/500 - What is an antigen ? ~ What is # is an antigen
#  473/500 - What currency does Luxembourg use ? ~ You # use What currency # use Luxembourg
#  474/500 - What is the population of Venezuela ? ~ What is # is the population of
#  475/500 - What type of polymer is used for bulletproof vests ? ~ You
#  476/500 - What currency does Argentina use ? ~ You # use What currency # use Argentina
#  477/500 - What is a thermometer ? ~ What is # is a thermometer
#  478/500 - What Canadian city has the largest population ? ~ You # has What # has Canadian city # has the largest population
#  479/500 - What color are crickets ? ~ You
#  480/500 - Which country gave New York the Statue of Liberty ? ~ You # gave Which country # gave New York # gave the Statue of
#  481/500 - What was the name of the first U.S. satellite sent into space ? ~ What was # was the name of
#  482/500 - What precious stone is a form of pure carbon ? ~ You # is What precious stone
#  483/500 - What kind of gas is in a fluorescent bulb ? ~ You
#  484/500 - What is rheumatoid arthritis ? ~ You # is What # is rheumatoid arthritis
#  485/500 - What river runs through Rowe , Italy ? ~ You # runs What river
#  486/500 - What is cerebral palsy ? ~ What is # is cerebral palsy
#  487/500 - What city is also known as `` The Gateway to the West '' ? ~ You
#  488/500 - How far away is the moon ? ~ How far # is the moon
#  489/500 - What is the source of natural gas ? ~ What is # is the source of
#  490/500 - In what spacecraft did U.S. astronaut Alan Shepard make his historic 1961 flight ? ~ You # did what spacecraft # make astronaut Alan Shepard # make his historic 1961 flight
#  491/500 - What is pectin ? ~ You # pectin What
#  492/500 - What is bio-diversity ? ~ What is # is bio
#  493/500 - What 's the easiest way to remove wallpaper ? ~ What 's # 's the easiest way remove # remove wallpaper
#  494/500 - What year did the Titanic start on its journey ? ~ You # did the Titanic start on
#  495/500 - How much of an apple is water ? ~ How much
#  496/500 - Who was the 22nd President of the US ? ~ Who was # was the 22nd President of
#  497/500 - What is the money they use in Zambia ? ~ What is # is the money use # use they
#  498/500 - How many feet in a mile ? ~ How many
#  499/500 - What is the birthstone of October ? ~ What is # is the birthstone of
#  500/500 - What is e-coli ? ~ You # is What # is e

# %%
enriched_training_data.to_csv(path_or_buf="./Dataset04svm/train_enriched.csv", index=False)
enriched_testing_data.to_csv(path_or_buf="./Dataset04svm/test_enriched.csv", index=False)

# %%
# feature extraction
vectorizer_enriched = TfidfVectorizer()

# fit: Estraiamo le feature tf-idf dal dataset
# transform: convertiamo le frasi del dataset in vettori tf-idf
X_train = vectorizer_enriched.fit_transform(enriched_training_data['questions'].tolist()) # matrice sparsa del training set. 
# transform: qui convertiamo solamente le frasi del dataset
X_test = vectorizer_enriched.transform(enriched_testing_data['questions'].tolist()) # e del testing set
y_train = enriched_training_data['classes'].tolist()
y_test = enriched_testing_data['classes'].tolist()

# %%
# usiamo il modello migliore SVM per tf-idf trovato nella lezione 5

from sklearn.metrics import classification_report
from sklearn.svm import SVC


svm = SVC(C=1.0, kernel='linear', degree=0, gamma=0.01, max_iter=-1, decision_function_shape='ovo')

svm.fit(X_train, y_train)

y_pred = svm.predict(X_test)

print(classification_report(y_pred, y_test, target_names=['ABBR', 'DESC', 'ENTY', 'HUM', 'LOC', 'NUM']))
# Out:
#               precision    recall  f1-score   support
#
#         ABBR       0.78      1.00      0.88         7
#         DESC       0.97      0.83      0.90       161
#         ENTY       0.72      0.80      0.76        85
#          HUM       0.92      0.86      0.89        70
#          LOC       0.83      0.88      0.85        76
#          NUM       0.88      0.98      0.93       101
#
#     accuracy                           0.87       500
#    macro avg       0.85      0.89      0.87       500
# weighted avg       0.88      0.87      0.87       500

# %% [markdown]
# Migliora di 5 punti percentuali!!!

# %% [markdown]
# ### Esercizio 4: Sostituisci i testi con le entità
# Per ogni frase nel dataset QuestionClassification, estrai le entità annotate dal modulo spacy solo per i nomi propri, di città e le date (`PROPN`, `GPE`, `DATE`) e sostituisci le porzioni di testo corrispondenti con il nome dell'entità. Ad esempio:
#
# - Frase iniziale  : '*In 1982, Mark drove his car from Los Angeles to Las Vegas until 5 of july*'
# - Frase modificata: '*In 1982, PERSON drove his car from GPE to GPE until DATE*'
#
# Salva le frasi arricchite in un nuovo dataframe, addestra un classificatore (SVM, NB, Rocchio..) e valutalo.
#
# **WARNING**: fare attenzione ai `compounds`, dovrebbero essere sostituiti da una singola entità. Per esempio: *Las Vegas* => `GPE`

# %%
def find_named_entities(sentence: str):
    entity_labels = nlp.get_pipe('ner').labels
    entity_found = []
    for entity_label in entity_labels:
        ents = search_entity(sentence, entity_label)
        if len(ents) != 0:
            entity_found.append(ents)
    return entity_found

def replace_named_entities(sentence: str):
    entities_to_replace = find_named_entities(sentence)
    for e in entities_to_replace:
        print(f"sostituisco {e[0][1]} al posto di {e[0][0]}")
        sentence = sentence.replace(e[0][0], e[0][1])
    return sentence

# NON E' PERFETTO, ma qualcosa fa (Impiega 8 min sul mio PC)
def replace_dataset(df) -> pd.DataFrame:
    data_dict = df.to_dict()
    questions : Dict[int, str] = data_dict["questions"]
    c = 0
    items = questions.items()
    l = len(items)
    for i, question in items:
        sentence_enriched = replace_named_entities(question)

        question = data_dict["questions"][i]

        if question != None:
            data_dict["questions"][i] = sentence_enriched
        else:
            f"question with id {i} skipped"
        
        c += 1
        print(f" {c}/{l} - {sentence_enriched}")
    return pd.DataFrame(data_dict)

training_data = pd.read_csv("./Dataset04svm/train.csv")
testing_data = pd.read_csv("./Dataset04svm/test.csv")


replaced_training_data = replace_dataset(training_data)
replaced_testing_data = replace_dataset(testing_data)
# Out:
# sostituisco GPE al posto di Russia
#  1/5452 - How did serfdom develop in and then leave GPE ?
# sostituisco PERSON al posto di Popeye Doyle
#  2/5452 - What films featured the character PERSON ?
#  3/5452 - How can I find a list of celebrities ' real names ?
# sostituisco EVENT al posto di the Chinese Year of the
# sostituisco PRODUCT al posto di Monkey
#  4/5452 - What fowl grabs the spotlight after EVENT PRODUCT ?
#  5/5452 - What is the full form of .com ?
#  6/5452 - What contemptible scoundrel stole the cork from my lunch ?
# sostituisco FAC al posto di St. Louis Browns
#  7/5452 - What team did baseball 's FAC become ?
#  8/5452 - What is the oldest profession ?
#  9/5452 - What are liver enzymes ?
# sostituisco ORG al posto di The Old West
#  10/5452 - Name the scar-faced bounty hunter of ORG .
# sostituisco PERSON al posto di Ozzy Osbourne
#  11/5452 - When was PERSON born ?
#  12/5452 - Why do heavier objects travel downhill faster ?
# sostituisco WORK_OF_ART al posto di The Pride of the Yankees
#  13/5452 - Who was WORK_OF_ART ?
# sostituisco PERSON al posto di Gandhi
#  14/5452 - Who killed PERSON ?
#  15/5452 - What is considered the costliest disaster the insurance industry has ever faced ?
# sostituisco GPE al posto di U.S.
#  16/5452 - What sprawling GPE state boasts the most airports ?
#  17/5452 - What did the only repealed amendment to the U.S. Constitution deal with ?
# sostituisco EVENT al posto di WWII
# sostituisco NORP al posto di Jews
#  18/5452 - How many NORP were executed in concentration camps during EVENT ?
#  19/5452 - What is `` Nine Inch Nails '' ?
#  20/5452 - What is an annotated bibliography ?
# sostituisco EVENT al posto di Boxing Day
#  21/5452 - What is the date of EVENT ?
# sostituisco GPE al posto di Monopoly
#  22/5452 - What articles of clothing are tokens in GPE ?
# sostituisco CARDINAL al posto di 11
#  23/5452 - Name CARDINAL famous martyrs .
# sostituisco EVENT al posto di Olympic
#  24/5452 - What 's the EVENT motto ?
#  25/5452 - What is the origin of the name ` Scarlett ' ?
# sostituisco LANGUAGE al posto di English
# sostituisco ORDINAL al posto di second
#  26/5452 - What 's the ORDINAL-most-used vowel in LANGUAGE ?
#  27/5452 - Who was the inventor of silly putty ?
# sostituisco GPE al posto di the United States
#  28/5452 - What is the highest waterfall in GPE ?
# sostituisco GPE al posto di Myrtle Beach
#  29/5452 - Name a golf course in GPE .
# sostituisco CARDINAL al posto di two
# sostituisco LOC al posto di Chesapeake Bay
#  30/5452 - Which CARDINAL states enclose LOC ?
#  31/5452 - What does the abbreviation AIDS stand for ?
#  32/5452 - What does a spermologer collect ?
#  33/5452 - How many points make up a perfect fivepin bowling score ?
#  34/5452 - Which company that manufactures video-game hardware sells the `` super system '' ?
# sostituisco GPE al posto di Monopoly
# sostituisco ORG al posto di Community Chest
#  35/5452 - How many ORG cards are there in GPE ?
# sostituisco PERSON al posto di Mormons
#  36/5452 - What do PERSON believe ?
#  37/5452 - When did the neanderthal man live ?
#  38/5452 - In what religion was Isis the nature goddess ?
# sostituisco WORK_OF_ART al posto di The Swiss Family Robinson ''
#  39/5452 - Where do the adventures of `` WORK_OF_ART take place ?
#  40/5452 - What relative of the racoon is sometimes known as the cat-bear ?
# sostituisco GPE al posto di Yahoo
#  41/5452 - How can I register my website in GPE for free ?
# sostituisco ORDINAL al posto di first
# sostituisco PERSON al posto di Edwin L. Drake
#  42/5452 - What was cash-conscious Colonel PERSON the ORDINAL to drill ?
# sostituisco LANGUAGE al posto di French
#  43/5452 - How many people in the world speak LANGUAGE ?
# sostituisco ORG al posto di the Venus de Milo
#  44/5452 - How many inches over six feet is ORG ?
#  45/5452 - How do they find or choose witnesses to an execution ?
# sostituisco DATE al posto di 1920s
# sostituisco PERSON al posto di Tony
#  46/5452 - What DATE cowboy star rode PERSON the Wonder Horse ?
# sostituisco ORG al posto di Stirred-Not Shaken
# sostituisco PERSON al posto di John Doxat
#  47/5452 - What cocktail inspired PERSON to write the book ORG ?
# sostituisco LOC al posto di Caribbean
#  48/5452 - What ISPs exist in the LOC ?
#  49/5452 - How do you ask a total stranger out on a date ?
# sostituisco ORG al posto di Apollo
#  50/5452 - What weapon is the mythological character ORG most proficient with ?
# sostituisco LOC al posto di Galapagos Islands
#  51/5452 - What country do the LOC belong to ?
#  52/5452 - What is ethology ?
# sostituisco NORP al posto di Muslim
#  53/5452 - Who was the prophet of the NORP people ?
#  54/5452 - Where did the term `` 86ed '' come from ?
# sostituisco ORG al posto di Snoopy
#  55/5452 - Who is ORG 's arch-enemy ?
#  56/5452 - What is the nature of learning ?
# sostituisco PERSON al posto di Johnny Cash
#  57/5452 - What 's the only color PERSON wears on stage ?
#  58/5452 - What 's the term for a young fox ?
# sostituisco CARDINAL al posto di six
# sostituisco GPE al posto di U.S.
#  59/5452 - What GPE state lived under CARDINAL flags ?
# sostituisco LOC al posto di Kashmir
#  60/5452 - What is the LOC issue ?
# sostituisco PERSON al posto di Loop
#  61/5452 - Where is the PERSON ?
#  62/5452 - What does `` extended definition '' mean and how would one write a paper on it ?
# sostituisco GPE al posto di Tirana
#  63/5452 - What country 's capital is GPE ?
#  64/5452 - What is titanium ?
#  65/5452 - Who do Herb and Tootsie live next door to ?
# sostituisco GPE al posto di Los Angeles
#  66/5452 - Which city has the oldest relationship as a sister city with GPE ?
#  67/5452 - What is a caldera ?
#  68/5452 - Why do people get calluses ?
# sostituisco ORG al posto di Reims
#  69/5452 - What are the names of the tourist attractions in ORG ?
# sostituisco GPE al posto di Wakefield
# sostituisco PERSON al posto di Cushman
#  70/5452 - What are PERSON and GPE known for ?
# sostituisco LOC al posto di Danube River
#  71/5452 - What body of water does the LOC flow into ?
# sostituisco ORG al posto di Scientology
#  72/5452 - Who is the founder of ORG ?
# sostituisco CARDINAL al posto di six
# sostituisco PERSON al posto di Musca
#  73/5452 - What does the CARDINAL-footed PERSON domestica become when it enters a house ?
#  74/5452 - What is the history of skateboarding ?
# sostituisco WORK_OF_ART al posto di Singing in the Rain and The Singing Nun
#  75/5452 - Who starred in WORK_OF_ART ?
#  76/5452 - How do I make fuel bricks from recycled newspaper ?
# sostituisco DATE al posto di 19th-century
# sostituisco GPE al posto di the Marquesas Islands
#  77/5452 - What DATE painter died in GPE ?
#  78/5452 - The corpus callosum is in what part of the body ?
# sostituisco ORG al posto di Headquarters U.S. European Command
#  79/5452 - How do I log on to home page at ORG ?
# sostituisco CARDINAL al posto di 1
# sostituisco ORG al posto di Nazis
#  80/5452 - What country did the ORG occupy for CARDINAL , CD NNS IN NNP NNP NNP .
# sostituisco GPE al posto di Nebraska
#  81/5452 - What is GPE 's most valuable resource ?
#  82/5452 - How many species of the Great White shark are there ?
#  83/5452 - What is the origin of head lice ?
# sostituisco GPE al posto di Mississippi
#  84/5452 - What is the nickname for the state of GPE ?
# sostituisco ORDINAL al posto di first
#  85/5452 - What was the ORDINAL domesticated bird ?
#  86/5452 - How many villi are found in the small intestine ?
# sostituisco ORG al posto di King Wenceslas
#  87/5452 - What country did ORG rule ?
#  88/5452 - What is a fear of shadows ?
# sostituisco CARDINAL al posto di five
# sostituisco PERSON al posto di Marx
#  89/5452 - Who were the CARDINAL PERSON brothers ?
# sostituisco DATE al posto di which year
# sostituisco GPE al posto di New Zealand
# sostituisco ORG al posto di ANZUS
#  90/5452 - In DATE was GPE excluded from the ORG alliance ?
# sostituisco ORG al posto di CNN
#  91/5452 - When did ORG begin broadcasting ?
#  92/5452 - What causes the body to shiver in cold temperatures ?
#  93/5452 - What are bear and bull markets ?
# sostituisco PERSON al posto di J.R.R. Tolkien
#  94/5452 - What PERSON book features Bilbo Baggins as the central character ?
#  95/5452 - What is `` dew point '' ?
# sostituisco PERSON al posto di Jesus
#  96/5452 - What is the meaning of PERSON ?
#  97/5452 - What company 's logo is a `` W '' in a circle ?
#  98/5452 - What is the definition of a cascade ?
# sostituisco PERSON al posto di Rococo
#  99/5452 - When did PERSON painting and architecture flourish ?
# sostituisco ORG al posto di Via
#  100/5452 - What country 's national passenger rail system is called ORG ?
#  101/5452 - Who invented Make-up ?
#  102/5452 - What is the origin of the word `` attic '' ?
# sostituisco ORG al posto di Samson
# sostituisco PERSON al posto di Delilah
#  103/5452 - What did PERSON do to ORG 's hair ?
# sostituisco ORG al posto di Paleozoic
#  104/5452 - What kind of animals were in the ORG era ?
# sostituisco PERSON al posto di Rhodes Scholar
#  105/5452 - Which of the following was PERSON ?
#  106/5452 - Who comprised the now-defunct comic book team known as the Champions ?
#  107/5452 - How do you make a paintball ?
# sostituisco GPE al posto di U.S.
#  108/5452 - What GPE state is Fort Knox in ?
#  109/5452 - What is a female rabbit called ?
# sostituisco GPE al posto di Japan
#  110/5452 - Where is the highest point in GPE ?
#  111/5452 - Where do chihuahuas come from ?
# sostituisco PERSON al posto di Barney Rubble
# sostituisco PRODUCT al posto di the `` Flintstones ''
#  112/5452 - Where does PERSON go to work after he drops Fred off in PRODUCT cartoon series ?
# sostituisco CARDINAL al posto di four
#  113/5452 - What are the world 's CARDINAL oceans ?
# sostituisco PERSON al posto di Michelangelo
#  114/5452 - What 's the only work by PERSON that bears his signature ?
#  115/5452 - What is the largest snake in the world ?
# sostituisco ORDINAL al posto di first
# sostituisco PERSON al posto di Stuart Hamblen
#  116/5452 - In what medium is PERSON considered to be the ORDINAL singing cowboy ?
# sostituisco ORG al posto di the International Lyrics Server
#  117/5452 - Where on the Internet can I find a song lyrics database similar to ORG ?
#  118/5452 - How much money does a back injury lawsuit get ?
#  119/5452 - What 's the common name for acetylsalicylic acid ?
# sostituisco ORG al posto di Georgetown
# sostituisco WORK_OF_ART al posto di Hoya
#  120/5452 - What does the ORG `` WORK_OF_ART '' mean ?
# sostituisco ORDINAL al posto di 5th
#  121/5452 - Where can I find a list of `` classic '' books ORDINAL and 6th graders should read ?
# sostituisco CARDINAL al posto di two
#  122/5452 - Which CARDINAL products use a tiger as their symbol ?
# sostituisco PERSON al posto di Pope
#  123/5452 - How is the election of a new PERSON announced to the world ?
# sostituisco CARDINAL al posto di one
#  124/5452 - How long does it take for your blood to make CARDINAL complete trip through the body ?
#  125/5452 - How do chickens have baby chicks ?
# sostituisco ORG al posto di Catholic Church
#  126/5452 - What is the historical relationship of ORG and bingo ?
#  127/5452 - How was the element calcium named ?
# sostituisco ORG al posto di The Andrews Sisters for Pistol Packin Mama
#  128/5452 - What crooner joined ORG ?
# sostituisco ORG al posto di the `` Instrument of the immortals
#  129/5452 - What piano company claims its product is ORG '' ?
# sostituisco PERSON al posto di Bounty
#  130/5452 - When did the PERSON mutiny take place ?
# sostituisco ORG al posto di BladeRunner
#  131/5452 - What novel inspired the movie ORG ?
#  132/5452 - What is a transistor ?
# sostituisco PERSON al posto di Jude Law
#  133/5452 - What is a film starring PERSON ?
# sostituisco DATE al posto di 1932
# sostituisco GPE al posto di Hollywood
# sostituisco PERSON al posto di Jean Harlow
#  134/5452 - What GPE dog died in the arms of PERSON in DATE ?
# sostituisco LOC al posto di Earth
#  135/5452 - What are the most common elements in the LOC 's crust ?
# sostituisco QUANTITY al posto di 2-foot-square
#  136/5452 - How much would it cost to purchase a QUANTITY party tent , with sides , ?
# sostituisco PERSON al posto di Oscar
#  137/5452 - What actress has received the most PERSON nominations ?
#  138/5452 - What are equity securities ?
#  139/5452 - What is gymnophobia ?
#  140/5452 - How many years do fossils take to form ?
# sostituisco ORG al posto di Orinoco
#  141/5452 - Where is the ORG ?
# sostituisco PRODUCT al posto di the `` Little Rascals ''
#  142/5452 - What was the name of PRODUCT dog ?
# sostituisco GPE al posto di Delaware
# sostituisco PERSON al posto di Penn
#  143/5452 - What city boasts PERSON 's Landing , on the banks of the GPE river ?
# sostituisco FAC al posto di Broadway
# sostituisco PERSON al posto di Cervantes
#  144/5452 - What FAC musical was inspired by PERSON 's Don Quixote ?
#  145/5452 - What is the origin of the word , JJ .
# sostituisco ORG al posto di Entebbe
#  146/5452 - How many hostages were killed in the ORG raid ?
#  147/5452 - How you can raise your IQ ?
# sostituisco ORG al posto di INRI
# sostituisco PERSON al posto di Jesus
#  148/5452 - What does ORG stand for when used on PERSON ' cross ?
# sostituisco PERSON al posto di Spumante
#  149/5452 - Who produces PERSON ?
#  150/5452 - Who earns their money the hard way ?
# sostituisco ORG al posto di the People 's Temple Commune
#  151/5452 - Who founded ORG ?
#  152/5452 - What athlete makes the most money from sports merchandise sales ?
#  153/5452 - How many bends are there in a standard paper clip ?
#  154/5452 - Who discovered electricity ?
#  155/5452 - What part of your body contains the corpus callosum ?
# sostituisco NORP al posto di American
# sostituisco ORDINAL al posto di first
#  156/5452 - Who was the ORDINAL NORP in space ?
# sostituisco CARDINAL al posto di two
# sostituisco GPE al posto di Brazil
# sostituisco NORP al posto di South American
#  157/5452 - What CARDINAL NORP countries do n't border GPE ?
# sostituisco DATE al posto di 1967
# sostituisco ORG al posto di Time
#  158/5452 - What album put The Beatles on the cover of ORG in DATE ?
#  159/5452 - What poem contains the line , `` grow old with me the best is yet to be '' .
#  160/5452 - What is a dental root canal ?
#  161/5452 - What war did the Wanna-Go-Home Riots occur after ?
# sostituisco DATE al posto di season
#  162/5452 - What is the busiest air travel DATE ?
#  163/5452 - What 's the colored part of the eye called ?
#  164/5452 - What are hook worms ?
# sostituisco EVENT al posto di the Rose Bowl
#  165/5452 - Where is EVENT played ?
# sostituisco NORP al posto di Japanese
#  166/5452 - Which NORP car maker had its biggest percentage of sale in the domestic market ?
# sostituisco ORG al posto di Marbella
#  167/5452 - Who is the mayor of ORG ?
# sostituisco PERSON al posto di Mojave
# sostituisco QUANTITY al posto di 14-mile
#  168/5452 - What sun-blasted , QUANTITY wide valley is just north of the PERSON desert ?
# sostituisco DATE al posto di what year
# sostituisco PERSON al posto di Thatcher
#  169/5452 - In DATE did PERSON become prime minister ?
# sostituisco LOC al posto di Earth
#  170/5452 - How many months does it take the moon to revolve around the LOC ?
# sostituisco CARDINAL al posto di 49
#  171/5452 - Where are the CARDINAL steps ?
# sostituisco DATE al posto di what year
# sostituisco GPE al posto di France
# sostituisco PERSON al posto di De Gaulle
#  172/5452 - In DATE was PERSON elected president of GPE ?
#  173/5452 - Who sings the themes for `` Dawson 's Creek '' and `` Felicity '' ?
#  174/5452 - Who directed `` Jaws '' ?
# sostituisco ORG al posto di T.V.
# sostituisco PERSON al posto di Tom Terrific
#  175/5452 - On what ORG show could PERSON be found ?
# sostituisco NORP al posto di Indian
# sostituisco ORG al posto di F Troop
#  176/5452 - What NORP tribe is ORG perpetually doing battle with ?
# sostituisco NORP al posto di Indian
#  177/5452 - Where did NORP Pudding come from ?
#  178/5452 - Why do some clothing labels say `` Use a nonchlorine bleach '' ?
# sostituisco EVENT al posto di the American Revolution
#  179/5452 - How many colonies were involved in EVENT ?
# sostituisco PERSON al posto di Maurizio Pellegrin
#  180/5452 - What is the name of the city that PERSON lives in ?
#  181/5452 - Where can I find pictorial directions on how to build a very simple treehouse ?
# sostituisco GPE al posto di Irkutsk
# sostituisco PERSON al posto di Kamchatka
#  182/5452 - What game 's board shows the territories of GPE , Yakutsk and PERSON ?
# sostituisco ORG al posto di Apricot Computer
#  183/5452 - What is the name of the managing director of ORG ?
# sostituisco ORG al posto di Nicholas Cage
#  184/5452 - What is the occupation of ORG ?
#  185/5452 - Why do horseshoes bring luck ?
# sostituisco CARDINAL al posto di 401
# sostituisco ORG al posto di K
#  186/5452 - What is the CARDINAL , ORG , plan ?
#  187/5452 - What causes pneumonia ?
# sostituisco DATE al posto di the three winter months
#  188/5452 - What are DATE in the southern hemisphere ?
#  189/5452 - What does gringo mean ?
# sostituisco LOC al posto di Africa
#  190/5452 - What country contains LOC 's northernmost point ?
#  191/5452 - What therapy attempts to elicit the `` primal scream '' ?
# sostituisco NORP al posto di Kalahari
#  192/5452 - Where is the NORP desert ?
# sostituisco GPE al posto di Ventura County
#  193/5452 - Which GPE police department seized the largest cocaine shipment in it 's history ?
# sostituisco PERSON al posto di Gotham
#  194/5452 - What city is sometimes called PERSON ?
#  195/5452 - What dangles over the tongue from the palate ?
# sostituisco PERSON al posto di Dennis the Menace
#  196/5452 - Who created PERSON ?
# sostituisco ORG al posto di Northwestern University
#  197/5452 - What dummy received an honorary degree from ORG ?
# sostituisco ORDINAL al posto di first
# sostituisco ORG al posto di Wall Street Journal
#  198/5452 - When was the ORDINAL ORG published ?
#  199/5452 - What countries have the largest areas of forest ?
#  200/5452 - How do I start a web based business ?
# sostituisco PERSON al posto di Name Alvin 's
#  201/5452 - PERSON brothers
# sostituisco ORG al posto di Eagle
#  202/5452 - What is ORG 's syndrome styloid process ?
# sostituisco PERSON al posto di Jayne Mansfield
#  203/5452 - How did PERSON die ?
# sostituisco ORG al posto di Fergie
# sostituisco PERSON al posto di Prince Andrew
#  204/5452 - When did the royal wedding of PERSON and ORG take place ?
# sostituisco DATE al posto di A Day
#  205/5452 - What actor said in DATE at the Races : `` Either he 's dead or my watch has stopped '' ?
# sostituisco GPE al posto di Iberia
#  206/5452 - What explorer was nicknamed GPE 's Pilot ?
# sostituisco DATE al posto di what year
# sostituisco ORG al posto di CNN
#  207/5452 - ORG began broadcasting in DATE ?
#  208/5452 - What is a ball that hits the foul pole called ?
#  209/5452 - What makes hamburgers taste like steakburgers ?
# sostituisco PERSON al posto di Mosaic
#  210/5452 - Which company created the Internet browser PERSON ?
# sostituisco ORG al posto di Judaism
#  211/5452 - What are the rites accompanying the circumcision of a newly born-child in ORG called ?
# sostituisco DATE al posto di 1960
#  212/5452 - What was the education system in the DATE 's ?
# sostituisco NORP al posto di South American
#  213/5452 - What NORP city has the world 's highest commercial landing field ?
#  214/5452 - How can I find out which cities have cable-modem access ?
# sostituisco PERSON al posto di Betsy Ross
#  215/5452 - What is PERSON famous for ?
#  216/5452 - How many species of sharks are there ?
#  217/5452 - What is `` snoogans '' ?
#  218/5452 - How many people are there in the world ?
#  219/5452 - What shrubs can be planted that will be safe from deer ?
# sostituisco DATE al posto di 1972
# sostituisco EVENT al posto di Watergate
#  220/5452 - What organization 's offices were broken into at EVENT in DATE ?
# sostituisco ORG al posto di Titanic
#  221/5452 - What is the design of the ship ORG ?
# sostituisco GPE al posto di S.O.S.
#  222/5452 - What does GPE stand for ?
#  223/5452 - Name a technique widely used to detect birth defects ?
# sostituisco DATE al posto di daily
#  224/5452 - What is the DATE requirement of folic acid for an expectant mother ?
# sostituisco TIME al posto di 7-minute
#  225/5452 - What is the `` TIME cigarette '' ?
# sostituisco CARDINAL al posto di four
#  226/5452 - What CARDINAL forms does gold occur in ?
# sostituisco ORG al posto di Chappellet
#  227/5452 - What is the acreage of the ORG vineyard ?
#  228/5452 - How do you correctly say the word ` qigong ' ?
#  229/5452 - When did beethoven die ?
#  230/5452 - How much does a new railroad coal car cost ?
# sostituisco CARDINAL al posto di two
# sostituisco EVENT al posto di the War of American Independence
# sostituisco NORP al posto di European
#  231/5452 - What CARDINAL NORP countries entered EVENT against the British ?
#  232/5452 - What is the filmmakers collabrative ?
# sostituisco NORP al posto di Russian
# sostituisco PRODUCT al posto di Prelude
#  233/5452 - What NORP composer 's PRODUCT in C Sharp Minor brought him fame and fortune ?
# sostituisco PERSON al posto di Harry Houdini 's
#  234/5452 - What caused PERSON death ?
# sostituisco GPE al posto di Windsor
#  235/5452 - Who was the mother of the man who would not be king , the duke of GPE ?
# sostituisco TIME al posto di three minutes
#  236/5452 - How many revolutions does a standard LP make in TIME ?
#  237/5452 - What is the name of the tallest mountain in the world ?
# sostituisco FAC al posto di Elm Street
# sostituisco ORG al posto di Nightmare
#  238/5452 - Where can I find a review of ORG on FAC in a film journal ?
# sostituisco EVENT al posto di Olympic
#  239/5452 - What 's the slowest EVENT swimming stroke ?
# sostituisco NORP al posto di Russian
# sostituisco ORDINAL al posto di first
#  240/5452 - What was the name of the ORDINAL NORP astronaut to do a spacewalk ?
#  241/5452 - What disease is transmitted by the Anopheles mosquito ?
# sostituisco CARDINAL al posto di one
#  242/5452 - What rum is so `` mixable '' it is a CARDINAL-brand bar ?
# sostituisco NORP al posto di South American
#  243/5452 - How many NORP countries have the letter Z in their names ?
# sostituisco CARDINAL al posto di 98
#  244/5452 - What is the contents of proposition CARDINAL ?
# sostituisco PERSON al posto di George Washington
#  245/5452 - Where was PERSON born ?
# sostituisco DATE al posto di December 21
# sostituisco GPE al posto di Lockerbie
# sostituisco PRODUCT al posto di Pan Am Flight 103
#  246/5452 - How many people on the ground were killed from the bombing of PRODUCT over GPE , Scotland , DATE , CD .
# sostituisco ORG al posto di NN DT NNP NNP ''
#  247/5452 - Who wrote ORG ?
#  248/5452 - What is paracetamol ?
# sostituisco ORG al posto di Green Lantern 's
#  249/5452 - What are the powers and weaknesses of ORG ring ?
# sostituisco DATE al posto di mosquito
# sostituisco ORG al posto di DT NN
#  250/5452 - Which DATE 's bite draws blood , ORG CC ORG .
# sostituisco GPE al posto di the United States
# sostituisco ORDINAL al posto di first
#  251/5452 - When was the ORDINAL steel mill in GPE built ?
# sostituisco DATE al posto di 1984
# sostituisco EVENT al posto di Olympics
# sostituisco NORP al posto di American
#  252/5452 - What diminutive NORP female gymnast stole the show at the DATE EVENT ?
# sostituisco PERSON al posto di Katie
#  253/5452 - What is the origin of the name PERSON ?
# sostituisco GPE al posto di Washington
# sostituisco ORG al posto di DC NN NN
#  254/5452 - What schools in the GPE , ORG VBP NN NN NN NN .
# sostituisco FAC al posto di the Berlin Wall
#  255/5452 - When did FAC go up ?
# sostituisco PERSON al posto di Terrence Malick
#  256/5452 - Who is PERSON ?
# sostituisco PERSON al posto di Ray Charles
#  257/5452 - What instrument is PERSON best known for playing ?
# sostituisco NORP al posto di Latin
#  258/5452 - What 's the meaning of the NORP battle cry : Ad arma , ad arma .
# sostituisco ORG al posto di Notre Dame University
#  259/5452 - What is the mascot for ORG ?
# sostituisco CARDINAL al posto di 84
# sostituisco DATE al posto di November , 1980
# sostituisco GPE al posto di Las Vegas
#  260/5452 - What GPE hotel burned in DATE , with the loss of CARDINAL lives ?
# sostituisco GPE al posto di Mount St. Helen
#  261/5452 - When did GPE last have a significant eruption ?
# sostituisco ORG al posto di CNN
#  262/5452 - ORG is the abbreviation for what ?
# sostituisco EVENT al posto di World War I
#  263/5452 - When did EVENT start ?
#  264/5452 - How many feet are there in a fathom ?
# sostituisco GPE al posto di Canada
#  265/5452 - What is a GPE two-penny black ?
# sostituisco GPE al posto di Nicois
# sostituisco NORP al posto di European
#  266/5452 - What NORP city do GPE live in ?
# sostituisco PERSON al posto di Beanie Baby
#  267/5452 - How can I find out what year a PERSON was introduced ?
#  268/5452 - What is the classic definition of tragic hero ?
# sostituisco ORG al posto di Microsoft
# sostituisco PRODUCT al posto di Windows 3
#  269/5452 - To what does ORG 's PRODUCT owe its success ?
# sostituisco DATE al posto di 1994
# sostituisco GPE al posto di Afghanistan
#  270/5452 - Who was President of GPE in DATE ?
#  271/5452 - What are other ways of getting stretch marks besides pregnancy , weight loss , and weight lifting ?
#  272/5452 - What did brontosauruses eat ?
#  273/5452 - What color bottles do good Rhine wines come in ?
# sostituisco GPE al posto di Seattle
#  274/5452 - Who was the lead actress in the movie ` Sleepless in GPE ' ?
# sostituisco GPE al posto di the United States
# sostituisco ORDINAL al posto di 16th
#  275/5452 - Who was the ORDINAL President of GPE ?
# sostituisco CARDINAL al posto di two
# sostituisco WORK_OF_ART al posto di Ozzie and Harriet Nelson
#  276/5452 - Who are the CARDINAL sons of WORK_OF_ART ?
#  277/5452 - What is molybdenum ?
# sostituisco EVENT al posto di Boxing Day
#  278/5452 - When is EVENT ?
# sostituisco NORP al posto di American
#  279/5452 - What is the lowest level of the NORP judiciary ?
# sostituisco LOC al posto di Somme
#  280/5452 - When was the battle of the LOC fought ?
# sostituisco PERSON al posto di Randy Craft
#  281/5452 - How many people did PERSON kill ?
# sostituisco GPE al posto di Canada
#  282/5452 - What 's the official animal of GPE ?
# sostituisco PERSON al posto di Spielberg
#  283/5452 - When did PERSON direct `` Jaws '' ?
#  284/5452 - What is the size of the largest akita ?
#  285/5452 - What animal has the biggest eyes ?
# sostituisco GPE al posto di California
#  286/5452 - What is GPE 's capital ?
# sostituisco WORK_OF_ART al posto di `` The Cuckoo 's Egg : Tracking a Spy Through the Maze of Computer Espionage ''
#  287/5452 - Who was the author of the book about computer hackers called WORK_OF_ART ?
#  288/5452 - Who was the founding member of the Pink Floyd band ?
# sostituisco NORP al posto di European
# sostituisco PERSON al posto di Budweis
#  289/5452 - What NORP country is home to the beer-producing city of PERSON ?
#  290/5452 - How do I find the balance of my social security account ?
# sostituisco DATE al posto di Valentine 's Day
#  291/5452 - What is the history of DATE cards ?
# sostituisco PERSON al posto di Christopher Columbus
#  292/5452 - Where was PERSON born ?
# sostituisco NORP al posto di Italians
#  293/5452 - What do NORP call Florence ?
# sostituisco FAC al posto di the Eiffel Tower
#  294/5452 - How do you get to the top of FAC ?
#  295/5452 - What does ` PSI ' stand for ?
# sostituisco NORP al posto di Romans
#  296/5452 - What sea did the NORP call mare nostrum ?
#  297/5452 - What 's the term for a bet before cards are dealt ?
# sostituisco CARDINAL al posto di 2
# sostituisco ORDINAL al posto di first
# sostituisco ORG al posto di Genesis
#  298/5452 - Which came ORDINAL , according to ORG 1 : CARDINAL : CARDINALCARDINAL - the chicken or the egg ?
#  299/5452 - What city did the Flintstones live in ?
# sostituisco NORP al posto di Latin
#  300/5452 - What is NORP for incompetent ?
#  301/5452 - What chemicals are used in lethal injection ?
# sostituisco CARDINAL al posto di No.1
#  302/5452 - What toy company is the world 's CARDINAL maker of female apparel ?
#  303/5452 - What board game does a `` wood-pusher '' play poorly ?
#  304/5452 - Which Doonesbury character was likely to turn into a werewolf ?
#  305/5452 - What is the abbreviation for micro ?
# sostituisco CARDINAL al posto di 7
#  306/5452 - What are the CARDINAL articles of the constitution ?
# sostituisco PERSON al posto di Super Bowls
#  307/5452 - Who has won the most PERSON ?
# sostituisco ORG al posto di NASDAQ
#  308/5452 - What does ORG stand for ?
# sostituisco PERSON al posto di BPH
#  309/5452 - What is PERSON ?
# sostituisco GPE al posto di US
#  310/5452 - What is the fastest commercial automobile that can be bought in the GPE ?
#  311/5452 - What stadium do the Miami Dolphins play their home games in ?
#  312/5452 - Who has the only speaking role in `` Silent Movie '' ?
#  313/5452 - Why is poop sometimes different colors ?
#  314/5452 - What was Einstein 's IQ ?
# sostituisco DATE al posto di 1942
# sostituisco PERSON al posto di Pearl Harbor
#  315/5452 - What day was PERSON attacked in DATE ?
# sostituisco WORK_OF_ART al posto di Teddy
#  316/5452 - What girl 's name is `` WORK_OF_ART '' an affectionate form of ?
# sostituisco PERSON al posto di John F. Kennedy
#  317/5452 - What state is PERSON buried in ?
#  318/5452 - What is the best way to remove wallpaper ?
# sostituisco GPE al posto di U.S.
#  319/5452 - What GPE state has an element named for it ?
# sostituisco ORG al posto di the Academy Awards
#  320/5452 - What company tabulates the ballots in voting for ORG ?
#  321/5452 - How did the tradition of best man start ?
# sostituisco ORG al posto di Titanic
#  322/5452 - How many years ago did the ship ORG sink ?
# sostituisco LOC al posto di the Arctic Ocean
#  323/5452 - What is the deepest area of LOC ?
# sostituisco DATE al posto di Halloween
#  324/5452 - What are DATE 's colors ?
#  325/5452 - How is silk screening done ?
# sostituisco GPE al posto di El Paso
#  326/5452 - What is the latitude and longitude of GPE , Texas ?
#  327/5452 - Who made a boat out of gopher wood ?
# sostituisco ORDINAL al posto di Fifth
#  328/5452 - Where can I find a `` ORDINAL Element '' screensaver ?
# sostituisco GPE al posto di Bloom County
#  329/5452 - Which GPE resident wreaks havoc with a computer ?
#  330/5452 - How do you match a name to a social security number ?
#  331/5452 - How does a rainbow form ?
#  332/5452 - What is the normal resting heart rate of a healthy adult ?
# sostituisco GPE al posto di Ohio
#  333/5452 - What is the population of GPE ?
#  334/5452 - How many calories are there in a Big Mac ?
# sostituisco ORG al posto di Hazmat
#  335/5452 - ORG stands for what ?
#  336/5452 - What creature scares people in the film `` Jaws '' ?
# sostituisco GPE al posto di America
# sostituisco PERSON al posto di John Peter Zenger
#  337/5452 - What part did PERSON play in the deveopment of the newspaper in GPE ?
# sostituisco ORG al posto di Caesar
#  338/5452 - Who followed ORG ?
# sostituisco CARDINAL al posto di four
#  339/5452 - What are the CARDINAL elements ?
# sostituisco CARDINAL al posto di a million
# sostituisco ORDINAL al posto di first
#  340/5452 - Who was the ORDINAL woman golfer to earn CARDINAL ?
#  341/5452 - What 's the tallest piece on a chessboard ?
# sostituisco ORG al posto di Answers.com
#  342/5452 - What is ORG 's address ?
#  343/5452 - Where can I buy movies on videotape online ?
# sostituisco ORG al posto di Frito-Lay
#  344/5452 - Who does the advertizing for ORG ?
# sostituisco ORG al posto di Trans Union Company
#  345/5452 - Who is the leading competitor of ORG ?
# sostituisco PERSON al posto di Robert Conrad
#  346/5452 - What product did PERSON dare people to knock off his shoulder ?
#  347/5452 - Who invented the radio ?
# sostituisco GPE al posto di U.K.
# sostituisco NORP al posto di American
# sostituisco QUANTITY al posto di 8 pounds
#  348/5452 - What 's the NORP dollar equivalent for QUANTITY in the GPE ?
#  349/5452 - What are the different approaches of systems analysis ?
#  350/5452 - How do doctors diagnose bone cancer ?
# sostituisco PERSON al posto di Piggy
#  351/5452 - Who is the man behind the pig-the man who pulls the strings and speaks for Miss PERSON ?
# sostituisco LOC al posto di the Mississippi River
#  352/5452 - What is the speed of LOC ?
#  353/5452 - What are the developmental stages of a swimmer ?
# sostituisco PERSON al posto di James Bond
#  354/5452 - What actor first portrayed PERSON ?
#  355/5452 - What ocean is the largest in the world ?
# sostituisco DATE al posto di 1948
# sostituisco NORP al posto di American
# sostituisco ORDINAL al posto di first
# sostituisco WORK_OF_ART al posto di the Nobel Prize
#  356/5452 - Who was the ORDINAL NORP poet to win WORK_OF_ART for literature , in DATE ?
# sostituisco ORG al posto di the Professional Golfers Association
# sostituisco PERSON al posto di Jack Nicklaus
#  357/5452 - What year did PERSON join ORG tour ?
# sostituisco PERSON al posto di Shakespeare
#  358/5452 - How many sonnets did PERSON write ?
#  359/5452 - What causes the redness in your cheeks when you blush ?
# sostituisco DATE al posto di 1991
# sostituisco WORK_OF_ART al posto di the Nobel Peace Prize
#  360/5452 - Who won WORK_OF_ART in DATE ?
#  361/5452 - Who are the Challengers of the Unknown ?
# sostituisco ORG al posto di the Pheonix Club
#  362/5452 - Define ORG ?
# sostituisco NORP al posto di Muslims
# sostituisco ORG al posto di Christian Crusaders
#  363/5452 - Which city did ORG fight to recapture from the NORP ?
# sostituisco WORK_OF_ART al posto di Rupee Depreciates ''
#  364/5452 - What does it mean `` WORK_OF_ART ?
# sostituisco LOC al posto di Mississippi
#  365/5452 - What gaming devices were dubbed `` LOC marbles '' and `` Memphis dominoes '' ?
# sostituisco ORDINAL al posto di first
# sostituisco ORG al posto di the Cleveland Browns
#  366/5452 - Who was the ORDINAL coach of ORG ?
#  367/5452 - How successful is arometherapy ?
# sostituisco DATE al posto di the start of the
# sostituisco EVENT al posto di Mideast War
# sostituisco NORP al posto di Jewish
#  368/5452 - What NORP holiday saw DATE 1973 EVENT ?
#  369/5452 - How does a copier work ?
# sostituisco LOC al posto di the Mississippi River
#  370/5452 - What is the speed of LOC ?
# sostituisco DATE al posto di 1969
# sostituisco EVENT al posto di Super Bowl III
#  371/5452 - Who said of EVENT in DATE : `` We 'll win- I guarantee it '' ?
# sostituisco PERSON al posto di Dudley
#  372/5452 - What is PERSON Do-Right 's horse 's name ?
#  373/5452 - Who declared : `` I am down on whores and I shan 't stop ripping them '' ?
#  374/5452 - Where does chocolate come from ?
#  375/5452 - What TV game show once saw a contestant admit to picking his toes in the shower ?
# sostituisco NORP al posto di Soviet
# sostituisco ORG al posto di a Rolls-Royce
#  376/5452 - What NORP leader owned ORG ?
# sostituisco DATE al posto di 1991
#  377/5452 - Where can I find a case on Individuals with Disabilities Education Act of DATE ?
# sostituisco PERSON al posto di Florence Nightingale
#  378/5452 - What war did PERSON tend the troops in ?
# sostituisco PRODUCT al posto di Stardust
#  379/5452 - Who wrote the song , `` PRODUCT '' ?
# sostituisco MONEY al posto di 1
# sostituisco PERSON al posto di Beatles
#  380/5452 - How many PERSON ' records went #MONEY ?
# sostituisco DATE al posto di 22 years
# sostituisco GPE al posto di Canada
#  381/5452 - Who is the only prime minister of GPE to serve DATE but not necessarily consecutively ?
# sostituisco ORG al posto di ` General Motors '
#  382/5452 - What is the abbreviation of the company name ORG ?
# sostituisco GPE al posto di Arkansas
#  383/5452 - What mountains lie between the GPE and Missouri rivers ?
# sostituisco DATE al posto di 1989
# sostituisco WORK_OF_ART al posto di the Will Rogers Award
#  384/5452 - Who received WORK_OF_ART in DATE ?
# sostituisco ORG al posto di RAM
#  385/5452 - What is the function of ORG ?
# sostituisco LOC al posto di Earth
# sostituisco PERSON al posto di Yellow Dwarf
# sostituisco PRODUCT al posto di G2 Spectrum
#  386/5452 - What 's the closest PRODUCT PERSON to LOC ?
#  387/5452 - How many equal angles are there in an isosceles triangle ?
#  388/5452 - What is the fear of cockroaches called ?
# sostituisco ORG al posto di CBS
# sostituisco PERSON al posto di John F. Kennedy 's
#  389/5452 - What ORG soap opera was interrupted by the bulletin of PERSON assassination ?
# sostituisco TIME al posto di 24-hour
#  390/5452 - What is the use of a TIME clock instead of a 12-hour clock ?
# sostituisco PERSON al posto di Randy Craft
#  391/5452 - What was the name of the lawyer who represented PERSON ?
# sostituisco GPE al posto di United States
#  392/5452 - What GPE President had dreamed that he was assassinated ?
# sostituisco DATE al posto di 1965
# sostituisco PERSON al posto di Lee Marvin
#  393/5452 - What film did PERSON win the DATE best actor Oscar for ?
# sostituisco NORP al posto di Basque
#  394/5452 - Where is NORP country located ?
# sostituisco PERSON al posto di Olsen
#  395/5452 - What product does `` Mrs. PERSON '' promote ?
# sostituisco PERSON al posto di Hirohito
#  396/5452 - What time of day did Emperor PERSON die ?
#  397/5452 - What is dry ice ?
# sostituisco PERSON al posto di Euchre
#  398/5452 - What 's the most powerful card in PERSON ?
# sostituisco PERSON al posto di keratoma
#  399/5452 - What does `` intractable plantar PERSON '' mean ?
# sostituisco ORG al posto di Ulysses
# sostituisco PERSON al posto di James Joyce
#  400/5452 - How many years did it take PERSON to write ORG ?
#  401/5452 - What crop failure caused the Irish Famine ?
# sostituisco NORP al posto di South Korean
# sostituisco ORG al posto di Kimpo International Airport
#  402/5452 - What NORP city is served by ORG ?
# sostituisco CARDINAL al posto di three
#  403/5452 - How many types of dogs ' tails are there - CARDINAL
#  404/5452 - What is the longest-running television series ?
# sostituisco LOC al posto di Antarctica
#  405/5452 - What predators exist on LOC ?
#  406/5452 - What is the difference between a generator and an alternator ?
#  407/5452 - How is energy created ?
# sostituisco CARDINAL al posto di three
#  408/5452 - What beer advertised that it had `` CARDINAL rings '' ?
# sostituisco EVENT al posto di the Vietnam war
# sostituisco NORP al posto di American
#  409/5452 - What is the quantity of NORP soldiers still unaccounted for from EVENT ?
# sostituisco DATE al posto di December 12
# sostituisco PERSON al posto di George Grant
#  410/5452 - What golfing accessory was patented by PERSON on DATE
#  411/5452 - What are the different types of plastic ?
#  412/5452 - How is it correct to say ` qigong ' ?
# sostituisco LOC al posto di Mount Everest
#  413/5452 - What was the highest mountain on earth before LOC was discovered ?
# sostituisco DATE al posto di 1797-185
# sostituisco GPE al posto di the Ligurian Republic
#  414/5452 - Where was GPE , DATE , ?
#  415/5452 - What country 's people are the top television watchers ?
#  416/5452 - When was the women 's suffrage amendment ratified ?
# sostituisco GPE al posto di New Zealand
# sostituisco NORP al posto di Polynesian
#  417/5452 - What NORP people inhabit GPE ?
# sostituisco NORP al posto di Roman
#  418/5452 - What movie tour of the NORP empire features the admonition : `` Row well and live '' ?
# sostituisco GPE al posto di Nevada
#  419/5452 - What GPE center has been dubbed The Biggest Little City in the World ?
# sostituisco CARDINAL al posto di 219
# sostituisco GPE al posto di North Delaware Street
#  420/5452 - What President lived at CARDINAL GPE , Independence , Missouri ?
# sostituisco NORP al posto di American Indians
#  421/5452 - Give a reason for NORP oftentimes dropping out of school .
#  422/5452 - Where must a soccer goalie stand to be permitted to handle the ball ?
#  423/5452 - What is the difference between classical conditioning and operant conditioning ?
# sostituisco GPE al posto di U.S.
# sostituisco ORDINAL al posto di first
#  424/5452 - In what GPE state was the ORDINAL woman governor elected ?
#  425/5452 - What are some interesting facts and information about dogsledding ?
# sostituisco PERSON al posto di Hitler
#  426/5452 - What year did PERSON die ?
# sostituisco PERSON al posto di Billy Joel
#  427/5452 - What famous model was married to PERSON ?
# sostituisco PERSON al posto di Babar
#  428/5452 - What kind of animal is PERSON ?
# sostituisco PERSON al posto di Jane Goodall
#  429/5452 - What is PERSON known for ?
# sostituisco PERSON al posto di Bob Marley
#  430/5452 - What killed PERSON ?
# sostituisco ORG al posto di Dumbo
#  431/5452 - How much money are ORG 's ears insured for ?
# sostituisco DATE al posto di 1941
# sostituisco PERSON al posto di Fred Astaire
#  432/5452 - Who danced into stardom with PERSON in DATE 's You 'll Never Get Rich ?
# sostituisco PERSON al posto di Stein Eriksen
#  433/5452 - Who is PERSON ?
# sostituisco PERSON al posto di Billie
#  434/5452 - What does the name PERSON mean ?
#  435/5452 - Who is the fastest swimmer in the world ?
# sostituisco LOC al posto di Africa
#  436/5452 - What is the highest peak in LOC ?
# sostituisco GPE al posto di U.S.
# sostituisco ORG al posto di Procter & Gamble
#  437/5452 - Where is ORG headquartered in the GPE ?
# sostituisco FAC al posto di The Garden of Allah
#  438/5452 - What desert has been called FAC ?
# sostituisco CARDINAL al posto di two
#  439/5452 - What do bicornate animals have CARDINAL of ?
#  440/5452 - What function does a community 's water tower serve ?
#  441/5452 - What is a fear of weakness ?
# sostituisco GPE al posto di Ohio
#  442/5452 - How many miles is it to GPE from North Carolina ?
# sostituisco QUANTITY al posto di an inch
#  443/5452 - How much snow equals QUANTITY of rain ?
# sostituisco ORG al posto di G.M.T.
#  444/5452 - What does ORG stand for ?
# sostituisco NORP al posto di Inuit
# sostituisco PERSON al posto di Eskimo
#  445/5452 - What does NORP and PERSON mean ?
#  446/5452 - What song served as the closing theme of The Johnny Cash Show ?
# sostituisco PERSON al posto di William Beers
#  447/5452 - What field sport did dentist PERSON promote and write a standard book of rules for ?
#  448/5452 - How do I tie dye clothes ?
# sostituisco ORDINAL al posto di first
#  449/5452 - When does the average teenager ORDINAL have intercourse ?
#  450/5452 - Why doesn 't www.answers.com have any answers to my questions ?
# sostituisco WORK_OF_ART al posto di All My Yesterdays
#  451/5452 - What actor 's autobiography is titled WORK_OF_ART ?
# sostituisco GPE al posto di U.S.
# sostituisco NORP al posto di Russian
# sostituisco PERSON al posto di Emil Goldfus
#  452/5452 - What NORP master spy lived in the GPE under the name PERSON ?
# sostituisco ORDINAL al posto di 19th
#  453/5452 - Where 's the ORDINAL hole on a golf course ?
#  454/5452 - What 's nature 's purpose for tornadoes ?
# sostituisco ORG al posto di Angels
# sostituisco PERSON al posto di Charlie
#  455/5452 - Who played the original PERSON 's ORG ?
#  456/5452 - Where can I find a person 's address from a telephone number ?
# sostituisco LANGUAGE al posto di English
# sostituisco NORP al posto di French
#  457/5452 - What LANGUAGE word comes from the Old NORP covrefeu , meaning cover fire ?
# sostituisco PERSON al posto di Prewitt
#  458/5452 - What musical instrument did PERSON play in James Jones 's From Here to Eternity ?
# sostituisco ORG al posto di Sarge Steel
#  459/5452 - Where did ORG get his metal hand ?
#  460/5452 - What makes popcorn pop ?
# sostituisco ORG al posto di Iguana
# sostituisco WORK_OF_ART al posto di The Night
#  461/5452 - Who wrote WORK_OF_ART of the ORG ?
#  462/5452 - Where does your hair grow the fastest ?
# sostituisco CARDINAL al posto di 197
# sostituisco PERSON al posto di King Gustav V
#  463/5452 - What country did PERSON reign over from CARDINAL to 195 ?
#  464/5452 - Who painted Mother and Child ?
# sostituisco LOC al posto di the Mississippi River
#  465/5452 - What is the speed of LOC ?
# sostituisco EVENT al posto di the Six Day War
#  466/5452 - In what area of the world was EVENT fought ?
# sostituisco LOC al posto di Earth
#  467/5452 - What is the brightest star visible from LOC ?
# sostituisco PERSON al posto di Robert Redford 's
#  468/5452 - What film marked PERSON directorial debut ?
# sostituisco ORDINAL al posto di second
# sostituisco PERSON al posto di Mao
#  469/5452 - What was PERSON 's ORDINAL name ?
# sostituisco PERSON al posto di Jude Law
#  470/5452 - What film or films has PERSON appeared in ?
#  471/5452 - Where do hyenas live ?
# sostituisco WORK_OF_ART al posto di Queen Mother ''
#  472/5452 - Who is the `` WORK_OF_ART ?
# sostituisco GPE al posto di Belgium
#  473/5452 - What 's the most commonly-spoken language in GPE ?
#  474/5452 - Who has more DNA - a man or a woman ?
# sostituisco ORG al posto di Maid-Rites
#  475/5452 - What are ORG ?
#  476/5452 - What children 's tale contains the line : `` Come , Cinderslut , and hold this skein of wool for me '' ?
#  477/5452 - What level of government or governmental agency is responsible for dealing with racism ?
#  478/5452 - How many referees work a soccer game ?
#  479/5452 - What cocktail do you concoct with whisky and sweet vermouth ?
# sostituisco LANGUAGE al posto di Spanish
#  480/5452 - How do you say `` fresh '' in LANGUAGE ?
#  481/5452 - What do bee hives do in cranberry bogs ?
# sostituisco ORG al posto di Lynmouth
#  482/5452 - What caused the ORG floods ?
# sostituisco EVENT al posto di the Tulip Festival
# sostituisco GPE al posto di Michigan
#  483/5452 - When is EVENT in GPE ?
# sostituisco ORG al posto di El Nino
#  484/5452 - Who came up with the name , ORG ?
# sostituisco PERSON al posto di Madilyn Kahn
#  485/5452 - What movie did PERSON star in with Gene Wilder ?
# sostituisco FAC al posto di the Golden Gate Bridge
#  486/5452 - What type of bridge is FAC ?
#  487/5452 - What dictator has the nickname `` El Maximo '' ?
# sostituisco FAC al posto di Slightly
#  488/5452 - What stereo manufacturer is `` FAC ahead of its time '' ?
# sostituisco GPE al posto di U.S.
# sostituisco WORK_OF_ART al posto di The Queen of the Pacific
#  489/5452 - What GPE city is WORK_OF_ART ?
# sostituisco PERSON al posto di Ethel Potter
#  490/5452 - What TV sitcom character had the maiden name PERSON ?
# sostituisco FAC al posto di Lifesaver
# sostituisco ORDINAL al posto di first
#  491/5452 - What was the ORDINAL FAC flavor ?
# sostituisco LANGUAGE al posto di English
#  492/5452 - Who kept the most famous diary in the LANGUAGE language ?
# sostituisco CARDINAL al posto di 1
#  493/5452 - Where can I find out the top CARDINAL singles ?
#  494/5452 - How many degrees cooler is the inside of a cucumber than the air outside ?
# sostituisco NORP al posto di Spanish
#  495/5452 - What NORP artist painted Crucifixion ?
# sostituisco NORP al posto di Jewish
#  496/5452 - What is the NORP bible called ?
#  497/5452 - Why is the grass green ?
#  498/5452 - What is a firewall ?
# sostituisco GPE al posto di Moscow
# sostituisco ORG al posto di The Times of London
# sostituisco PERSON al posto di Reuter
#  499/5452 - What spy novelist served as GPE correspondent for PERSON and ORG ?
# sostituisco NORP al posto di Japanese
#  500/5452 - Which oil company almost picked a word that meant `` stalled car '' in NORP as its new international name ?
# sostituisco ORG al posto di Spider-Man 's
#  501/5452 - How long does it take for ORG web to evaporate ?
# sostituisco PERSON al posto di Randy Steven Craft 's
#  502/5452 - Who was PERSON lawyer ?
# sostituisco LOC al posto di the Spice Island
#  503/5452 - What was known as LOC ?
# sostituisco ORDINAL al posto di first
# sostituisco ORG al posto di Person to Person
#  504/5452 - Who was the ORDINAL host of ORG ?
# sostituisco PERSON al posto di Ranger
#  505/5452 - Name the PERSON who was always after Yogi Bear .
# sostituisco ORG al posto di the Wheel of Fortune
# sostituisco PERSON al posto di Death
#  506/5452 - What deck of cards includes ORG , the Lovers , and PERSON ?
# sostituisco FAC al posto di the Statue of Liberty
#  507/5452 - What does FAC wear on her feet ?
#  508/5452 - Who is the superstar in rent-a-cars ?
# sostituisco FAC al posto di McCarren Airport
#  509/5452 - FAC is located in what city ?
#  510/5452 - What household facility contains a float ball , ballcock , and overflow tube ?
# sostituisco PERSON al posto di Betty Boop 's
#  511/5452 - What was the name of PERSON dog ?
#  512/5452 - What fraction of a beaver 's life is spent swimming ?
# sostituisco PERSON al posto di Luis Rey
#  513/5452 - What was the Bridge of San PERSON made of ?
#  514/5452 - What do economists do ?
#  515/5452 - What country has the largest sheep population ?
# sostituisco DATE al posto di a year
# sostituisco GPE al posto di Dominica
#  516/5452 - What do I need to do to take my dog with me to live in GPE , West Indies for DATE ?
#  517/5452 - What country is the world 's largest importer of cognac ?
# sostituisco PRODUCT al posto di Johnnie Walker Black Label
#  518/5452 - How many years is PRODUCT aged ?
#  519/5452 - What does SIDS stand for ?
# ...
#  267/500 - What is dianetics ?
# sostituisco GPE al posto di Ethiopia
#  268/500 - What is the capital of GPE ?
#  269/500 - For how long is an elephant pregnant ?
# sostituisco PERSON al posto di Janice Joplin
#  270/500 - How did PERSON die ?
# sostituisco GPE al posto di Iceland
#  271/500 - What is the primary language in GPE ?
#  272/500 - What is the difference between AM radio stations and FM radio stations ?
#  273/500 - What is osteoporosis ?
# sostituisco GPE al posto di U.S.
# sostituisco ORDINAL al posto di first
#  274/500 - Who was the ORDINAL woman governor in the GPE ?
#  275/500 - What is peyote ?
#  276/500 - What is the esophagus used for ?
#  277/500 - What is viscosity ?
# sostituisco GPE al posto di Oklahoma
#  278/500 - What year did GPE become a state ?
# sostituisco GPE al posto di Texas
#  279/500 - What is the abbreviation for GPE ?
#  280/500 - What is a mirror made out of ?
#  281/500 - Where on the body is a mortarboard worn ?
# sostituisco ORG al posto di J.F.K.
#  282/500 - What was ORG 's wife 's name ?
# sostituisco GPE al posto di I.V.
#  283/500 - What does GPE stand for ?
#  284/500 - What is the chunnel ?
# sostituisco PERSON al posto di Hitler
#  285/500 - Where is PERSON buried ?
#  286/500 - What are antacids ?
#  287/500 - What is pulmonary fibrosis ?
# sostituisco PERSON al posto di Quaaludes
#  288/500 - What are PERSON ?
#  289/500 - What is naproxen ?
#  290/500 - What is strep throat ?
# sostituisco GPE al posto di U.S.
#  291/500 - What is the largest city in the GPE ?
#  292/500 - What is foot and mouth disease ?
#  293/500 - What is the life expectancy of a dollar bill ?
#  294/500 - What do you call a professional map drawer ?
# sostituisco PRODUCT al posto di Aborigines
#  295/500 - What are PRODUCT ?
#  296/500 - What is hybridization ?
#  297/500 - What color is indigo ?
# sostituisco GPE al posto di Italy
#  298/500 - How old do you have to be in order to rent a car in GPE ?
#  299/500 - What does a barometer measure ?
#  300/500 - What color is a giraffe 's tongue ?
# sostituisco ORG al posto di USPS
#  301/500 - What does ORG stand for ?
# sostituisco ORG al posto di NFL
#  302/500 - What year did the ORG go on strike ?
#  303/500 - What is solar wind ?
# sostituisco PERSON al posto di Neil Armstrong
#  304/500 - What date did PERSON land on the moon ?
# sostituisco GPE al posto di Hiroshima
#  305/500 - When was GPE bombed ?
# sostituisco LOC al posto di the Savannah River
#  306/500 - Where is LOC ?
# sostituisco EVENT al posto di the Vietnam War
# sostituisco ORDINAL al posto di first
#  307/500 - Who was the ORDINAL woman killed in EVENT ?
#  308/500 - What planet has the strongest magnetic field of all the planets ?
# sostituisco GPE al posto di Alaska
#  309/500 - Who is the governor of GPE ?
# sostituisco GPE al posto di Italy
# sostituisco PERSON al posto di Mussolini
#  310/500 - What year did PERSON seize power in GPE ?
# sostituisco GPE al posto di Persia
#  311/500 - What is the capital of GPE ?
# sostituisco FAC al posto di the Eiffel Tower
#  312/500 - Where is FAC ?
#  313/500 - How many hearts does an octopus have ?
#  314/500 - What is pneumonia ?
# sostituisco GPE al posto di US
#  315/500 - What is the deepest lake in the GPE ?
#  316/500 - What is a fuel cell ?
# sostituisco GPE al posto di U.S.
# sostituisco ORDINAL al posto di first
#  317/500 - Who was the ORDINAL GPE president to appear on TV ?
# sostituisco ORG al posto di the Little League Museum
#  318/500 - Where is ORG ?
#  319/500 - What are the two types of twins ?
#  320/500 - What is the brightest star ?
#  321/500 - What is diabetes ?
# sostituisco PERSON al posto di Kennedy
#  322/500 - When was President PERSON shot ?
# sostituisco ORG al posto di TMJ
#  323/500 - What is ORG ?
#  324/500 - What color is yak milk ?
# sostituisco PERSON al posto di Dwight D. Eisenhower
#  325/500 - What date was PERSON born ?
# sostituisco ORG al posto di ISDN
#  326/500 - What does the technical term ORG mean ?
#  327/500 - Why is the sun yellow ?
# sostituisco MONEY al posto di between dollars and pounds
#  328/500 - What is the conversion rate MONEY ?
# sostituisco PERSON al posto di Abraham Lincoln
#  329/500 - When was PERSON born ?
#  330/500 - What is the Milky Way ?
#  331/500 - What is mold ?
# sostituisco PERSON al posto di Mozart
#  332/500 - What year was PERSON born ?
#  333/500 - What is a group of frogs called ?
# sostituisco PERSON al posto di William Penn 's
#  334/500 - What is the name of PERSON ship ?
#  335/500 - What is the melting point of gold ?
# sostituisco ORG al posto di the White House
#  336/500 - What is the street address of ORG ?
#  337/500 - What is semolina ?
#  338/500 - What fruit is Melba sauce made from ?
# sostituisco ORG al posto di Ursa Major
#  339/500 - What is ORG ?
#  340/500 - What is the percentage of water content in the human body ?
#  341/500 - How much does water weigh ?
# sostituisco PERSON al posto di Lyndon Johnson
#  342/500 - What was President PERSON 's reform program called ?
# sostituisco GPE al posto di Windsor , Ontario
#  343/500 - What is the murder rate in GPE ?
# sostituisco CARDINAL al posto di 2
#  344/500 - Who is the only president to serve CARDINAL non-consecutive terms ?
# sostituisco GPE al posto di Australia
#  345/500 - What is the population of GPE ?
#  346/500 - Who painted the ceiling of the Sistine Chapel ?
#  347/500 - Name a stimulant .
#  348/500 - What is the effect of volcanoes on the climate ?
# sostituisco PERSON al posto di Andy Griffith
#  349/500 - What year did the PERSON show begin ?
#  350/500 - What is acid rain ?
# sostituisco GPE al posto di Mexico
#  351/500 - What is the date of GPE 's independence ?
# sostituisco LOC al posto di Lake Champlain
#  352/500 - What is the location of LOC ?
# sostituisco GPE al posto di Illinois
#  353/500 - What is the GPE state flower ?
# sostituisco GPE al posto di Maryland
#  354/500 - What is GPE 's state bird ?
#  355/500 - What is quicksilver ?
# sostituisco WORK_OF_ART al posto di The Divine Comedy ''
#  356/500 - Who wrote `` WORK_OF_ART ?
#  357/500 - What is the speed of light ?
#  358/500 - What is the width of a football field ?
# sostituisco CARDINAL al posto di zero
#  359/500 - Why in tennis are CARDINAL points called love ?
#  360/500 - What kind of dog was Toto in the Wizard of Oz ?
#  361/500 - What is a thyroid ?
#  362/500 - What does ciao mean ?
#  363/500 - What is the only artery that carries blue blood from the heart to the lungs ?
# sostituisco ORG al posto di Yellowstone National Park
#  364/500 - How often does Old Faithful erupt at ORG ?
#  365/500 - What is acetic acid ?
# sostituisco GPE al posto di St. Louis
#  366/500 - What is the elevation of GPE , MO ?
#  367/500 - What color does litmus paper turn when it comes into contact with a strong acid ?
# sostituisco NORP al posto di German
#  368/500 - What are the colors of the NORP flag ?
# sostituisco ORG al posto di the Moulin Rouge
#  369/500 - What is ORG ?
# sostituisco LOC al posto di the Black Sea
# sostituisco NORP al posto di soviet
#  370/500 - What NORP seaport is on LOC ?
#  371/500 - What is the atomic weight of silver ?
# sostituisco GPE al posto di Brazil
#  372/500 - What currency do they use in GPE ?
#  373/500 - What are pathogens ?
#  374/500 - What is mad cow disease ?
#  375/500 - Name a food high in zinc .
# sostituisco GPE al posto di North Carolina
#  376/500 - When did GPE enter the union ?
#  377/500 - Where do apple snails live ?
#  378/500 - What are ethics ?
# sostituisco ORG al posto di CPR
#  379/500 - What does ORG stand for ?
#  380/500 - What is an annuity ?
# sostituisco PERSON al posto di John F. Kennedy
#  381/500 - Who killed PERSON ?
# sostituisco GPE al posto di U.S.
# sostituisco ORDINAL al posto di first
#  382/500 - Who was the ORDINAL vice president of the GPE ?
#  383/500 - What birthstone is turquoise ?
# sostituisco GPE al posto di US
# sostituisco ORDINAL al posto di first
#  384/500 - Who was the ORDINAL GPE President to ride in an automobile to his inauguration ?
# sostituisco GPE al posto di the United States
#  385/500 - How old was the youngest president of GPE ?
# sostituisco PERSON al posto di Ulysses S. Grant
#  386/500 - When was PERSON born ?
# sostituisco PERSON al posto di Muscular Dystrophy
#  387/500 - What is PERSON ?
# sostituisco PERSON al posto di Neuschwanstein
#  388/500 - Who lived in the PERSON castle ?
#  389/500 - What is propylene glycol ?
#  390/500 - What is a panic disorder ?
# sostituisco ORG al posto di Polaroid
#  391/500 - Who invented the instant ORG camera ?
#  392/500 - What is a carcinogen ?
#  393/500 - What is a baby lion called ?
#  394/500 - What is the world 's population ?
#  395/500 - What is nepotism ?
#  396/500 - What is die-casting ?
#  397/500 - What is myopia ?
# sostituisco GPE al posto di New York
#  398/500 - What is the sales tax rate in GPE ?
#  399/500 - Developing nations comprise what percentage of the world 's population ?
# sostituisco ORDINAL al posto di fourth
#  400/500 - What is the ORDINAL highest mountain in the world ?
# sostituisco PERSON al posto di Shakespeare
#  401/500 - What is PERSON 's nickname ?
#  402/500 - What is the heaviest naturally occurring element ?
#  403/500 - When is Father 's Day ?
# sostituisco ORG al posto di NASA
#  404/500 - What does the acronym ORG stand for ?
# sostituisco LOC al posto di the Columbia River
#  405/500 - How long is LOC in miles ?
# sostituisco WORK_OF_ART al posto di The Star
#  406/500 - What city 's newspaper is called `` WORK_OF_ART '' ?
#  407/500 - What is carbon dioxide ?
#  408/500 - Where is the Mason/Dixon line ?
# sostituisco GPE al posto di Boston
#  409/500 - When was the GPE tea party ?
#  410/500 - What is metabolism ?
# sostituisco GPE al posto di U.S.A.
# sostituisco WORK_OF_ART al posto di Laugh-In ''
#  411/500 - Which GPE president appeared on `` WORK_OF_ART ?
#  412/500 - What are cigarettes made of ?
# sostituisco GPE al posto di Zimbabwe
#  413/500 - What is the capital of GPE ?
# sostituisco ORG al posto di NASA
#  414/500 - What does ORG stand for ?
# sostituisco GPE al posto di Michigan
#  415/500 - What is the state flower of GPE ?
#  416/500 - What are semiconductors ?
#  417/500 - What is nuclear power ?
#  418/500 - What is a tsunami ?
# sostituisco GPE al posto di Texas
#  419/500 - Who is the congressman from state of GPE on the armed forces committee ?
# sostituisco DATE al posto di 1913
#  420/500 - Who was president in DATE ?
# sostituisco ORDINAL al posto di first
#  421/500 - When was the ORDINAL kidney transplant ?
# sostituisco CARDINAL al posto di two
# sostituisco GPE al posto di Canada
#  422/500 - What are GPE 's CARDINAL territories ?
# sostituisco LOC al posto di Atlantic
# sostituisco ORG al posto di Lindbergh
#  423/500 - What was the name of the plane ORG flew solo across the LOC ?
#  424/500 - What is genocide ?
# sostituisco GPE al posto di Argentina
#  425/500 - What continent is GPE on ?
# sostituisco DATE al posto di the late eighth century
# sostituisco ORG al posto di Vikings
#  426/500 - What monastery was raided by ORG in DATE ?
#  427/500 - What is an earthquake ?
#  428/500 - Where is the tallest roller coaster located ?
#  429/500 - What are enzymes ?
#  430/500 - Who discovered oxygen ?
#  431/500 - What is bangers and mash ?
# sostituisco ORG al posto di Louisiana State University
# sostituisco PERSON al posto di Tiger
#  432/500 - What is the name given to the PERSON at ORG ?
# sostituisco NORP al posto di British
#  433/500 - Where are the NORP crown jewels kept ?
# sostituisco LOC al posto di the North Pole
# sostituisco ORDINAL al posto di first
#  434/500 - Who was the ORDINAL person to reach LOC ?
#  435/500 - What is an ulcer ?
#  436/500 - What is vertigo ?
#  437/500 - What is the spirometer test ?
# sostituisco DATE al posto di first day of summer
#  438/500 - When is the official DATE ?
# sostituisco ORG al posto di SOS
#  439/500 - What does the abbreviation ORG mean ?
# sostituisco GPE al posto di Britain
#  440/500 - What is the smallest bird in GPE ?
#  441/500 - Who invented Trivial Pursuit ?
#  442/500 - What gasses are in the troposphere ?
#  443/500 - Which country has the most water pollution ?
#  444/500 - What is the scientific name for elephant ?
# sostituisco PERSON al posto di Gypsy
#  445/500 - Who is the actress known for her role in the movie `` PERSON '' ?
# sostituisco ORG al posto di the Beverly Hillbillies
#  446/500 - What breed of hunting dog did ORG own ?
# sostituisco LOC al posto di Earth
#  447/500 - What is the rainiest place on LOC ?
# sostituisco NORP al posto di African American
# sostituisco ORDINAL al posto di first
# sostituisco WORK_OF_ART al posto di the Nobel Prize
#  448/500 - Who was the ORDINAL NORP to win WORK_OF_ART in literature ?
# sostituisco GPE al posto di St. Patrick 's Day
#  449/500 - When is GPE ?
# sostituisco PERSON al posto di FDR
#  450/500 - What was PERSON 's dog 's name ?
#  451/500 - What colors need to be mixed to get the color pink ?
# sostituisco GPE al posto di Japan
#  452/500 - What is the most popular sport in GPE ?
#  453/500 - What is the active ingredient in baking soda ?
# sostituisco PERSON al posto di Thomas Jefferson
#  454/500 - When was PERSON born ?
#  455/500 - How cold should a refrigerator be ?
#  456/500 - When was the telephone invented ?
#  457/500 - What is the most common eye color ?
# sostituisco GPE al posto di the United States
# sostituisco ORDINAL al posto di first
#  458/500 - Where was the ORDINAL golf course in GPE ?
#  459/500 - What is schizophrenia ?
#  460/500 - What is angiotensin ?
# sostituisco PERSON al posto di Jesse Jackson
#  461/500 - What did PERSON organize ?
# sostituisco GPE al posto di New York 's
#  462/500 - What is GPE state bird ?
# sostituisco GPE al posto di Utah
# sostituisco LOC al posto di the National Park
#  463/500 - What is LOC in GPE ?
# sostituisco PERSON al posto di Susan B. Anthony 's
#  464/500 - What is PERSON birthday ?
# sostituisco LOC al posto di the Catskill Mountains
#  465/500 - In which state would you find LOC ?
#  466/500 - What do you call a word that is spelled the same backwards and forwards ?
#  467/500 - What are pediatricians ?
# sostituisco GPE al posto di Bentonville
#  468/500 - What chain store is headquartered in GPE , Arkansas ?
#  469/500 - What are solar cells ?
#  470/500 - What is compounded interest ?
#  471/500 - What are capers ?
#  472/500 - What is an antigen ?
# sostituisco GPE al posto di Luxembourg
#  473/500 - What currency does GPE use ?
# sostituisco GPE al posto di Venezuela
#  474/500 - What is the population of GPE ?
#  475/500 - What type of polymer is used for bulletproof vests ?
# sostituisco GPE al posto di Argentina
#  476/500 - What currency does GPE use ?
#  477/500 - What is a thermometer ?
# sostituisco NORP al posto di Canadian
#  478/500 - What NORP city has the largest population ?
#  479/500 - What color are crickets ?
# sostituisco FAC al posto di the Statue of Liberty
# sostituisco GPE al posto di New York
#  480/500 - Which country gave GPE FAC ?
# sostituisco GPE al posto di U.S.
# sostituisco ORDINAL al posto di first
#  481/500 - What was the name of the ORDINAL GPE satellite sent into space ?
#  482/500 - What precious stone is a form of pure carbon ?
#  483/500 - What kind of gas is in a fluorescent bulb ?
#  484/500 - What is rheumatoid arthritis ?
# sostituisco GPE al posto di Rowe
#  485/500 - What river runs through GPE , Italy ?
#  486/500 - What is cerebral palsy ?
# sostituisco WORK_OF_ART al posto di The Gateway to the West ''
#  487/500 - What city is also known as `` WORK_OF_ART ?
#  488/500 - How far away is the moon ?
#  489/500 - What is the source of natural gas ?
# sostituisco DATE al posto di 1961
# sostituisco GPE al posto di U.S.
# sostituisco PERSON al posto di Alan Shepard
#  490/500 - In what spacecraft did GPE astronaut PERSON make his historic DATE flight ?
#  491/500 - What is pectin ?
#  492/500 - What is bio-diversity ?
#  493/500 - What 's the easiest way to remove wallpaper ?
# sostituisco ORG al posto di Titanic
#  494/500 - What year did the ORG start on its journey ?
#  495/500 - How much of an apple is water ?
# sostituisco GPE al posto di US
# sostituisco ORDINAL al posto di 22nd
#  496/500 - Who was the ORDINAL President of the GPE ?
# sostituisco GPE al posto di Zambia
#  497/500 - What is the money they use in GPE ?
# sostituisco QUANTITY al posto di a mile
#  498/500 - How many feet in QUANTITY ?
# sostituisco DATE al posto di October
#  499/500 - What is the birthstone of DATE ?
#  500/500 - What is e-coli ?

# %%
replaced_training_data.to_csv(path_or_buf="./Dataset04svm/train_replaced.csv", index=False)
replaced_testing_data.to_csv(path_or_buf="./Dataset04svm/test_replaced.csv", index=False)

# %%
# feature extraction
vectorizer_replaced = TfidfVectorizer()

# fit: Estraiamo le feature tf-idf dal dataset
# transform: convertiamo le frasi del dataset in vettori tf-idf
X_train2 = vectorizer_replaced.fit_transform(replaced_training_data['questions'].tolist()) # matrice sparsa del training set. 
# transform: qui convertiamo solamente le frasi del dataset
X_test2 = vectorizer_replaced.transform(replaced_testing_data['questions'].tolist()) # e del testing set
y_train2 = replaced_training_data['classes'].tolist()
y_test2 = replaced_testing_data['classes'].tolist()

# %%
# usiamo il modello migliore SVM per tf-idf trovato nella lezione 5

from sklearn.metrics import classification_report
from sklearn.svm import SVC


svm = SVC(C=1.0, kernel='linear', degree=0, gamma=0.01, max_iter=-1, decision_function_shape='ovo')

svm.fit(X_train2, y_train2)

y_pred2 = svm.predict(X_test2)

print(classification_report(y_pred2, y_test2, target_names=['ABBR', 'DESC', 'ENTY', 'HUM', 'LOC', 'NUM']))
# Out:
#               precision    recall  f1-score   support
#
#         ABBR       0.78      1.00      0.88         7
#         DESC       0.99      0.82      0.89       166
#         ENTY       0.72      0.83      0.77        82
#          HUM       0.89      0.89      0.89        65
#          LOC       0.85      0.86      0.86        80
#          NUM       0.86      0.97      0.91       100
#
#     accuracy                           0.87       500
#    macro avg       0.85      0.90      0.87       500
# weighted avg       0.88      0.87      0.87       500

# %% [markdown]
# Ehm... anche qui 87%. Le risposte NUM hanno un f1-score minore rispetto al caso precedente

# %% [markdown]
# ### Esercizio 5: Confronta i modelli
# Confronta i modelli degli esercizi 3 e 4 con un modello che hai addestrato nelle precedenti lezioni in termini di F1 measure.

# %% [markdown]
# ### Risposta
#
# Sono entrambi equivalenti. Ma e' meglio il primo perché impiega molto meno tempo e produce risultati migliori nelle risposte NUM.
